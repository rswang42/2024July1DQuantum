# %% [markdown]
# # Gaussian Based Flow: Solving 1D Schrödinger Equation Made Easy.
#
# ## Motivation
#
# In this notebook we aim to introduce a powerful variational framework,which enables Variational Monte Carlo(VMC) calculation on Gaussian-based, normalizingly-flowed wavefunctions. Calculations for the ground state and excited states are performed on a 1-dimensional quantum system as a minimun demonstration.
#
# ## System
#
# ### Hamiltonian
#
# Consider Hamiltonian
#
# $$
#   \hat H = -\frac{1}{2} \nabla^2 + \hat V
# $$
#
# with the following potential
#
# $$
# V(x) = 3x^4 + \frac{1}{2} x^3 - 3x^2
# $$
#
# Where $x$ is the one-dimensional coordinate of the particle.
#
# > Units in a.u.
#
# Plotting the potential:
#
# - First initialize discrete mesh

# %%
import sys
sys.path.append("../")
import numpy as np 
import matplotlib.pyplot as plt

# energy conversion factor
hartree2ev = 27.2107

xmin = -10; xmax = 10; Nmesh = 2000
xmesh = np.linspace(xmin, xmax, Nmesh)
h = xmesh[1] - xmesh[0]

# %% [markdown]
# - Then define the potential and plot it

# %%
def Vpot(x):
    return 3*x**4 + x**3/2 - 3*x**2

plt.plot(xmesh, [Vpot(x)*hartree2ev for x in xmesh], 'k-', lw=2, label="Potential")
plt.xlabel("x(Bohr)")
plt.ylabel("energy(eV)")
plt.xlim([-1.5,1.5])
plt.ylim([-40,45])
plt.legend()
plt.show()

# %% [markdown]
# > The potential is quite anharmonic!

# %% [markdown]
# ### Exact Results
#
# By finite differential, we can construct the Hamiltonian on discrete meshes and then exact diagonalize it to get the exact wavefunctions and energy levels.
#
# #### Ground State
#
# First let's inspect the ground state probability density $\rho(x) = |\psi(x)|^2$ and the ground state energy:

# %%
from scipy.linalg import eigh 
from VMC.utils import buildH

# Finite Differential Method
# which would be <exact> if our mesh intervals are small enough
H = buildH(Vpot,xmesh,Nmesh,h)
w, v = eigh(H)

# ground state wave function
gs_wf = v[:,0]
normalize_factor = (gs_wf**2).sum() * h
# probability density
gs_rho = gs_wf**2 / normalize_factor
    
print("Ground State Probability Density")
plt.plot(xmesh, gs_rho, label='FD', lw=2)
plt.xlim([-1.5,1.5])
plt.xlabel('$x$')
plt.ylabel(r'$\rho(x)$')
plt.legend()
plt.show()

print(f"Ground State Energy:{w[0]:.5f}(Hartree)")
# Out:
# Ground State Probability Density
# Ground State Energy:0.19457(Hartree)

# %% [markdown]
# #### Excited State
#
# 5 lowest energy levels

# %%
num_of_orbs = 5
print(f"Lowest {num_of_orbs} Energies:(Hartree)")
print(f"{w[:num_of_orbs:]}")
# Out:
# Lowest 5 Energies:(Hartree)
# [ 0.19456813  1.73513997  4.54932271  7.82492991 11.54729191]

# %% [markdown]
# ## Variational Calculation
#
# Let's move on to our variational calculation!
#
# ### Variational Principle
#
# Consider a time-independent Hamiltonian $\hat H$ and a normalized state $\psi$, we have
#
# - The energy expectation:
#
#     > NOTE: here $d\tau$ is the (general) integral element
#
# $$
# E=\int\psi^{*} \hat{H} \psi d \tau
# $$
#
# - Normalization:
#
# $$
# \int\psi^{*} \psi d \tau=1
# $$
#
# - Then we make an arbitrary infinitesimal variance to the wavefunction (a variation to wavefunction):
#
# $$
# \psi\to\phi=\psi+\delta\psi
# $$
#
# - Then we calculate the energy expectation of the newly get state $\phi$, denoting as $E + \delta E$:
#
# $$
# E+\delta E=\frac{\int\phi^{*} \hat{H} \phi d \tau} {\int\phi^{*} \phi d \tau}
# $$
#
# - Substituting the expression of $\phi$ into the formula above, omitting higer order terms and with some deductions, we have:
#
# $$
# \delta E=\int( \delta\psi^{*} \hat{H} \psi+\psi^{*} \hat{H} \delta\psi) d \tau-E \int( \delta\psi^{*} \psi+\psi^{*} \delta\psi) d \tau
# $$
#
# - Since $\delta \psi$ is arbitrary, we have the following deductions:
#   - If   $\psi$ satisfies $\hat H \psi = E \psi$, then $\delta E = 0$
#   - If   $(\delta E = 0 , \forall \delta \psi)$, then $\psi$ must satisfies $\hat H \psi = E \psi$
# - Which is exactly the **Variational Principle**:
#
#   > The expectation of $\hat H$ takes variational extremum $(\delta E = 0)$ $\Leftrightarrow$ $\psi$ is the eigenvector of $\hat H$
#
#
# ### Variational Method
#
# - Suppose all the eigenvalues of the Hamiltonian are (in ascending order):
#
# $$
# E_0, \quad E_1, \quad E_2, \quad \ldots
# $$
#
# - with corresponding eigenvectors:
#
# $$
# \psi_0, \quad \psi_1, \quad \psi_2, \quad \ldots
# $$
#
# - with $E_0$ and $\psi_0$ the ground state energy and ground state wavefunction.
#
# - Suppose the eigenvectors ${\psi_n}$ we have is already the complete basis of the Hilbert space, then any wavefunction $\phi$ in this Hilbert space could be expanded w.r.t. ${\psi_n}$:
#
# $$
# \phi=\sum_{n} c_{n} \psi_{n}, \qquad\sum_{n} | c_{n} |^{2}=1.
# $$
#
# - The energy expectation has the form:
#
# $$
# \langle\phi| \hat{H} | \phi\rangle=\int\phi^{*} \hat{H} \phi d \tau=\sum_{m n} c_{m}^{*} c_{n} \int\psi_{m}^{*} \hat{H} \psi_{n} d \tau=\sum_{n} | c_{n} |^{2} E_{n}.
# $$
#
# - Since $E_0$ is the ground state energy, we have
#
# $$
# \langle\phi| \hat{H} | \phi\rangle=\sum_{n} | c_{n} |^{2} E_{n} \geq E_{0}.
# $$
#
# - If and only if $\phi = \psi_0$, aka, $\phi$ is exactly the ground state wavefunction, we have $\langle\phi| \hat{H} | \phi\rangle= E_{0}$.
# - In other cases, the energy expectation of $\phi$ would be strictly greater than ground state energy.
# - Base on this, we can prepare several trial wavefunctions $\phi_i$, calculate their energy expectations, and select the one $\phi_k$ with the smallest energy $E_k$. The selected $E_k$ has the closest value compared to exact ground state energy $E_0$ amongst all trial wavefunctions and $\phi_k$ is closest to exact ground state wavefunciton $\psi_0$ amongst $\phi_i$.
#
# > However, `randomly` picking a wavefunction from the Hilbert space and praying it to be the ground state may seems idealistic.
# >
# > How can we `systematically` determine the wavefunction that holds the variational extremum of the energy expectation?
#
#
# > The answer is quite straingforward: **to introduce a** `variational parameter` **to the wavefunction**.
#
# #### Variational Calculation Framework
#
# - First, construct a wavefunction **with variational parameter** $\lambda$: $\phi(\lambda)$
#   - Note that $\phi(\lambda)$ is also called a **wavefunction ansatz**.
# - Then calculate the energy expectation of the trial wavefunction:
#
# $$
#   E(\lambda) = \langle\phi(\lambda)| \hat{H} | \phi(\lambda)\rangle
# $$
#
# - From the equation above, we have an energy expectation as a function of the variational parameter $\lambda$.
# - Then we reach the extremum of the energy expection by making derivative w.r.t. $\lambda$
#
# $$
#     \frac{dE(\lambda)}{d\lambda} \bigg|_{\lambda_0} = 0
# $$
#
# - And getting the $\lambda_0$ that satisfies the formula above, we have $E(\lambda_0)$ as the best approximation of ground  state energy $E_0$ and $\phi(\lambda_0)$
#
# ##### Excited States
#
# - Variational method could also be applied to excited states calculation.
# - Suppose we have already variationally settled all the states whose energies are smaller than $E_n$: the wavefunctions $(\phi_0,\phi_1,\ldots,\phi_{n-1})$, then we can make induction to find variational solution to n-th excitated state $\phi_n$.
#   - The constraint on our initial guess on $\phi_n$ should be: let $\phi_n$ **orthogonal to all the previous wavefunctions** $(\phi_0,\phi_1,\ldots,\phi_{n-1})$, we have
#
# $$
#   \psi( \lambda)=c_{n} \psi_{n}+c_{n+1} \psi_{n+1}+\cdots,
# $$
#
# $$
#   E ( \lambda)=c_{n}^{*} c_{n} E_{n}+c_{n+1}^{*} c_{n+1} E_{n+1}+\cdots\geq E_{n}.
# $$
#
# - Then applying the derivative method again, we have the best approximation to n-th excited state:
#
# $$
#   \phi_n(\lambda_0),\quad E_n(\lambda_0)
# $$
#
# > The following part of this notebook is organized as
# >
# > - Gaussian Flowed Trial Wavefunctions
# >   - The wavefunction ansatz utilizing normalizing flow, enables a straightforward excited states estimation.
# > - Energy Estimator by MCMC
# >   - Using Metropolis-Hastings algorithm to estimate the local energy.
# > - Optimization of the Variational Parameter
# >   - Utilizing AD to perform a gradient descent to find the best wavefunction.
# >
# > Which is in exactly the same order as we proposed in the Variational Calculation Framework part:
# >
# > - Trial Wavefunction $\phi(\lambda)$
# > - Energy Expectation $E(\lambda)$
# > - Finding Extremum $ \frac{dE(\lambda)}{d\lambda} \bigg|_{\lambda_0} = 0$
#
#
# ### Gaussian Flowed Trial Wavefunction
#
# To parameterize the trial wavefunction, typically one would directly introduce a variational parameter into wavefunction, for example a simple [four-parameter helium wavefunction](https://opencommons.uconn.edu/chem_educ/30/) :
#
# $$
#  \phi_{He}(\vec r_1, \vec r_2; \theta:=\{a, b, c, d\}) = e^{-2s}(1+\frac{u}{2}e^{au})(1 + bsu + ct^2 + du^2)
# $$
#
# where $s=r_1 + r_2$, $u=r_1 - r_2$, and $t=|\vec r_1 - \vec r_2|$ and $\theta$ is the variational parameter.
#
# Despite of directly constructing trial wavefunction like this, we can also implement the trial wavefunction with parameter $\theta$:
#
# $$
# \Psi(x;\theta) = \Phi(f_\theta(x))\left| \text{det}\left(\frac{\partial f_\theta(x)}{\partial x}\right) \right|^{\frac{1}{2}}
# $$
#
# where $f_\theta$ is a bijective neural network (NN) with parameter $\theta$ that mapping the original coordinate $x \rightarrow z = f_\theta(x)$, $\Phi$ the initial basis we choose and $|\text{det}(\partial f_\theta(x)/\partial x)|^{1/2}$ the Jacobian determinant of the mapping $f_\theta(x)$ w.r.t. $x$.
#
# By this kind of implementation, we are actually constructing a `normalizing flow` between two probability densities. For reference of normalizing flow, see [Normalizing Flows for Probabilistic Modeling and Inference](https://arxiv.org/abs/1912.02762v2). A concise illustration would be(from [Neural canonical transformations for vibrational spectra of molecules](https://pubs.aip.org/aip/jcp/article/161/2/024103/3302449/Neural-canonical-transformations-for-vibrational)):
#
# ![Normalizing Flow Wavefunction](./assets/Screenshot%202024-07-12%20165759.png)
#
# The initial basis $\Phi$ are chosen as the eigenstates of a one-dimensional harmonic oscillator:
#
# $$
# \Phi_{n} ( z )=\operatorname{e x p} \left(-\frac{1} {2} z^{2} \right) H_{n} \bigl(- z \bigr)
# $$
#
# Where $n$ refers to the energy level quantum number of the state, and $H_n$ the n-th order Hermite polynomial.
#
# Then we can construct an assembly of **orthogonal** wavefunctions
#
# $$
# \Phi_0,\quad \Phi_1, \quad \ldots
# $$
#
# Since they are the eigenvectors of one-dimensional harmonic oscillators.
#
# The **orthogonality is perserved throughout the flow transformation since the flow is an unitary transformation** ([m* of two-dimensional electron gas: A neural canonical transformation study](https://scipost.org/10.21468/SciPostPhys.14.6.154))
#
# Then we get the wavefunctions of different energy levels that are orthogonal to each other as we expected:
#
# $$
# \Psi_0(x;\theta),\Psi_1(x;\theta),\Psi_2(x;\theta),\ldots
# $$

# %% [markdown]
# The code below implement a simple residual-connected `MLP` flow using [Flax](https://flax.readthedocs.io/en/latest/) and define the wavefunction ansatz as stated above:

# %%
from functools import partial

import numpy as np
import jax
import jax.numpy as jnp
from flax import linen as flax_nn

jax.config.update("jax_enable_x64", True)

@partial(jax.custom_jvp, nondiff_argnums=(0,))
def hermite(n: int, x: float) -> jax.Array:
    """The hermite polynominals"""
    h0 = 1.0 / jnp.pi ** (1 / 4)
    h1 = jnp.sqrt(2.0) * x / jnp.pi ** (1 / 4)

    def body_fun(i, val):
        valm2, valm1 = val
        return valm1, jnp.sqrt(2.0 / i) * x * valm1 - jnp.sqrt((i - 1) / i) * valm2

    _, hn = jax.lax.fori_loop(2, n + 1, body_fun, (h0, h1))

    return jax.lax.cond(n > 0, lambda: hn, lambda: h0)


@hermite.defjvp
def hermite_jvp(n:int, primals, tangents):
    (x,) = primals
    (dx,) = tangents
    hn = hermite(n, x)
    dhn = jnp.sqrt(2 * n) * hermite((n - 1) * (n > 0), x) * dx
    primals_out, tangents_out = hn, dhn
    return primals_out, tangents_out


def wf_base(x: float | jax.Array, n: int, m=1) -> jax.Array:
    """The wave function ansatz (Gaussian)
    NOTE: 1D!

    Args:
        x: the 1D coordinate of the (single) particle.
        n: the excitation quantum number
        m: the particle mass(a.u.)

        NOTE: n=0 for GS!

    Returns:
        psi: the probability amplitude at x.
    """
    psi = (m ** (1 / 4)) * jnp.exp(-0.5 * m * (x**2)) * hermite(n, jnp.sqrt(m) * x)
    return psi


class WFAnsatz:
    """The flow wave function ansatz"""

    def __init__(
        self,
        flow: flax_nn.Module,
    ) -> None:
        self.flow = flow

    def wf_ansatz(
        self,
        params: jax.Array | np.ndarray | dict,
        x: float | jax.Array,
        n: int,
    ) -> jax.Array:
        """The flow transformed log wavefunction

        Args:
            params: the flow parameter
            x: the coordinate before flow
            n: the excitation quantum number

            NOTE: n=0 for GS!

        Returns:
            amplitude: the wavefunction
        """
        z = self.flow.apply(params, x)[0]
        phi = wf_base(z, n)

        def _flow_func(x):
            return self.flow.apply(params, x)[0]

        jac = jax.jacfwd(_flow_func)(x)
        jacdet = jnp.sqrt(jnp.abs(jac))
        amplitude = phi * jacdet
        return amplitude

class MLPFlow(flax_nn.Module):
    """A simple MLP flow"""

    out_dims: int
    mlp_width = 3

    @flax_nn.compact
    def __call__(self, x):
        _init_x = x
        x = x.reshape(
            1,
        )
        x = flax_nn.Dense(self.mlp_width)(x)
        x = flax_nn.sigmoid(x)
        x = flax_nn.Dense(self.mlp_width)(x)
        x = flax_nn.sigmoid(x)
        x = flax_nn.Dense(self.out_dims)(x)
        x = _init_x + x
        _init_x = x
        x = flax_nn.Dense(self.mlp_width)(x)
        x = flax_nn.sigmoid(x)
        x = flax_nn.Dense(self.mlp_width)(x)
        x = flax_nn.sigmoid(x)
        x = flax_nn.Dense(self.out_dims)(x)
        x = _init_x + x
        _init_x = x
        x = flax_nn.Dense(self.mlp_width)(x)
        x = flax_nn.sigmoid(x)
        x = flax_nn.Dense(self.mlp_width)(x)
        x = flax_nn.sigmoid(x)
        x = flax_nn.Dense(self.out_dims)(x)
        return _init_x + x

# %% [markdown]
# Then we try to initialize the flow and test the initialized Jacobian determinant is close to identity as we expect.
#
# > One of the important feature of the flow is that is should start from near identity transformation. To ensure this feature, we implement the residual network in the output layer so that the transformation would take the form of $z = f_\theta(x) = x + g_{\theta'}(x)$ where $g_{\theta'}$ denotes the network without the lase residual connection layer.
# >
# > This is quite like the backflow idea, and the near identity initialization is actually making the network learning the interactions from non-interacting states, mostly in an *adiabatic* manner.
#
# And to test this feature we inspect the Jacobian after initialization of the network:

# %%
# Initialize flow
key = jax.random.PRNGKey(42)
model_flow = MLPFlow(out_dims=1)
key, subkey = jax.random.split(key)
x_dummy = jnp.array(-1.0,dtype=jnp.float64)
key, subkey = jax.random.split(key)
params = model_flow.init(subkey, x_dummy)
# Initial Jacobian
init_jacobian = jax.jacfwd(lambda x: model_flow.apply(params, x))(x_dummy)
print(f"Init Jacobian = \n{init_jacobian}")
# Out:
# Init Jacobian =
# [0.99310585]

# %% [markdown]
# Visualization of the lowest 3 eigenvectors:

# %%
# The list containing the quantum number of eigenstates
state_indices = np.arange(3)
# Initialize Wavefunction
wf_ansatz_obj = WFAnsatz(flow=model_flow)
wf_ansatz = wf_ansatz_obj.wf_ansatz
wf_vmapped = jax.vmap(wf_ansatz, in_axes=(None, 0, 0))

# Plotting wavefunction
print("Wavefunction (Initialization)")
xmin = -10
xmax = 10
Nmesh = 2000
xmesh = np.linspace(xmin, xmax, Nmesh,dtype=np.float64)
mesh_interval = xmesh[1] - xmesh[0]
plt.figure()
for i in state_indices:
    wf_on_mesh = jax.vmap(wf_ansatz, in_axes=(None, 0, None))(params, xmesh, i)
    plt.plot(xmesh, wf_on_mesh, label=f"n={i}")
plt.xlim([-10, 10])
plt.legend()
plt.title("Wavefunction (Initialization)")
plt.show()
plt.close()
# Out:
# Wavefunction (Initialization)

# %% [markdown]
# ### Energy Estimator by MCMC
#
# In order to calculate the energy expectation of the given trial wavefunction, we need:
# 1. An energy estimator that estimate the local energy of a given wavefunction at position x:
#
# $$
# E_L(x;\theta) = \frac{\hat H \Psi(x;\theta)}{\Psi(x;\theta)}
# $$
#
# 2. An efficient algorithm to estimate the energy expectation:
#
# $$
#   \langle E\rangle_\theta
#   = \frac{\int \mathrm d x \, \Psi^*(x; \theta)\hat H \Psi(x; \theta) } {\int
#   \mathrm d x \,|\Psi(x; \theta)|^2}
# $$
#
# First let's make a straightforward implementation of the local energy estimator:

# %%
class EnergyEstimator:
    """Energy Estimator"""

    def __init__(self, wf_ansatz: callable) -> None:
        self.wf_ansatz = wf_ansatz

    def local_kinetic_energy(
        self,
        params: jax.Array | np.ndarray | dict,
        xs: jax.Array,
        state_indices: np.ndarray,
    ) -> jax.Array:
        """Local Kinetic Energy Estimator
        NOTE: per batch implementation.

        Args:
            params: the flow parameter
            xs: (num_of_orbs,) the 1D coordinate of the particle(s).
                The xs are in corresponding order as in state_indices.
            state_indices: (num_of_orbs,) the array containing
                the excitations in each bath, for example,
                [0,1,2] represents there are totally 3 number
                of orbitals: ground state: 0
                            first excitation state: 1
                            second excitation state: 2

        Returns:
            local_kinetic: the local kinetic energy.
        """
        single_laplacian_func = jax.grad(jax.grad(self.wf_ansatz, argnums=1), argnums=1)
        wf_vmapped = jax.vmap(self.wf_ansatz, in_axes=(None, 0, 0))
        laplacians = jax.vmap(single_laplacian_func, in_axes=(None, 0, 0))(
            params, xs, state_indices
        )
        local_kinetics = -0.5 * laplacians / wf_vmapped(params, xs, state_indices)
        return local_kinetics

    @staticmethod
    def local_potential_energy(
        xs: jax.Array,
    ) -> jax.Array:
        """Local Potential Energy Estimator

        Args:
            xs: (num_of_orbs,) the 1D coordinate of the particle(s).
                The xs are in corresponding order as in state_indices.
        Returns:
            local_potential: the local potential energy.
        """
        local_potentials = 3 * xs**4 + xs**3 / 2 - 3 * xs**2
        return local_potentials

    def local_energy(
        self,
        params: jax.Array | np.ndarray | dict,
        xs: jax.Array,
        state_indices: np.ndarray,
    ) -> jax.Array:
        """Local Energy Estimator

        Args:
            params: the flow parameter
            xs: (num_of_orbs,) the 1D coordinate of the particle(s).
                The xs are in corresponding order as in state_indices.
            state_indices: (num_of_orbs,) the array containing
                the excitations in each bath, for example,
                [0,1,2] represents there are totally 3 number
                of orbitals: ground state: 0
                            first excitation state: 1
                            second excitation state: 2

        Returns:
            local_energy: the local energy.
        """
        kin_energy = self.local_kinetic_energy(params, xs, state_indices)
        pot_energy = self.local_potential_energy(xs)
        local_energy = kin_energy + pot_energy
        return local_energy

# %% [markdown]
# Then let's randomly draw a sample between (-1.5,1.5) and estimate it's local energy w.r.t. the randomly initialized wavefunction:

# %%
# Local Energy Estimator
energy_estimator = EnergyEstimator(wf_ansatz=wf_ansatz)
x_test_local_energy = np.random.uniform(-1.5, 1.5, state_indices.shape)
x_test_local_energy = jnp.array(x_test_local_energy)
local_energy = energy_estimator.local_energy(
    params, x_test_local_energy, state_indices
)
print("Testing Local Energy Estimator:")
print(
    f"testing x: {x_test_local_energy}\n"
    f"state_indices: {state_indices}\n"
    f"Get local energy = {local_energy}"
)
# Out:
# Testing Local Energy Estimator:
# testing x: [-0.00942143 -1.01038527 -0.21797178]
# state_indices: [0 1 2]
# Get local energy = [0.48437168 0.56445392 2.28732086]

# %% [markdown]
# Now we have the local energy estimator, let's try to substitude the local energy expression into the expectation formula. We get the importance sampling algorithm that estimate the energy expectation efficiently:
#
# $$
# \begin{align*}
#   \langle E\rangle_\theta
#   &= \frac{\int \mathrm d x\, \Psi^*(x; \theta)\hat H \Psi(x; \theta) } {\int
#   \mathrm d x\,|\Psi(x; \theta)|^2} \\
#   &= \int \mathrm d x\, p(x; \theta) E_L(x; \theta) \\
#   &\approx \underset{x \sim p(x;\theta)} {\mathbb{E}} \left[ E_{L} ( x ) \right]
#   \\&\approx
#    \frac{1}{M} \sum_i^M E_L(x^{(i)}; \theta).
# \end{align*}
# $$
#
# This converts the energy expectation from the high dimensional integration into a Markov Chain Monte Carlo(MCMC) sampling problem, which significantly reduces the computational resources we need to estimate the expectations.
#
# The integral is approximated by drawing $M$ configurations $\left\{x^{(i)}\right\}$ that are sampled from the probability distribution defined by wavefunction:
#
# $$
#   p_\theta(x^{(i)})
#   = \frac{|\Psi(x^{(i)}; \theta)|^2 }{ \int \mathrm d x\,|\Psi(x; \theta)|^2}
# $$
#
# And then take statistical average over these values.
#
# An efficient way to sample according to $p(x;\theta)$ is the Metropolis-Hastings algorithm. It works by proposing moves $x'$ locally from a Gaussian distribution $N(x, \sigma)$ with mean $x$ and standard deviation $\sigma$. $\sigma$ is also called the step size. (The move proposal need not be Gaussian or even symmetric, but this choice works well for many cases.)
#
# The probability of accepting a proposed move $x \to x'$ in the Metropolis algorithm (symmetric move proposal) is given by
# $$
#   p(x \to x') = \text{min}\left(1, \frac{p(x')}{p(x)}\right) = \text{min}\left(1, \frac{|\Psi(x')|^2}{|\Psi(x)|^2}\right)
# $$
#
# If the probability calculated from the wavefunction at the proposed configuration is larger than at the original position, then the proposal is always accepted. If not, then the acceptance is proportional to the ratio of the wavefunction.
# If you want more information on the Metropolis algorithm, please refer to [Wikipedia article](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm).
#
# Observe that the wavefunction doesn't have to be normalized, since the normalization factor cancels out in the ratio. This is extremely useful!
#
# Here is another illustration helping to understand the difference between Metropolis method with conventional quadrature scheme: (from [Understanding Molecular Simulation](https://www.sciencedirect.com/book/9780122673511/understanding-molecular-simulation))
#
# ![Comparasion of convention quadrature and Metropolis](./assets/Screenshot%202024-07-12%20220905.png)
#
# > In this figure, we compare two ways of
#  measuring the depth of the river Nile, by conventional quadrature (left) and
#  byMetropolis sampling; that is, the construction of an importance-weighted
#  random walk (right). In the conventional quadrature scheme, the value of
#  the integrand is measured at a predetermined set of points. As the choice
#  of these points does not depend on the value of the integrand, many points
#  may be located in regions where the integrand vanishes. In contrast, in the
#  Metropolis scheme, a random walk is constructed through that region of
#  space where the integrand is nonnegligible (i.e., through the Nile itself). In
#  this random walk, a trial move is rejected if it takes you out of the water and
#  is accepted otherwise. After every trial move (accepted or not), the depth of
#  the water is measured. The (unweighted) averageof all these measurements
#  yields an estimate of the average depth of the Nile. This, then, is the essence
#  of the Metropolis method.
#
# A one-step metropolis as well as a mcmc core function that performs `steps` of configuration updates are implemented as follow:

# %%
class Metropolis:
    """The Metropolis Algorithm
    iterating the positions of MCMC walkers according
    to the Metropolis algorithm.
    """

    def __init__(self, wf_ansatz: callable) -> None:
        self.wf_ansatz = wf_ansatz

    def oneshot_sample(
        self,
        xs: jax.Array,
        state_indices: np.ndarray,
        probability: jax.Array,
        params: jax.Array | np.ndarray | dict,
        step_size: float,
        key: jax.random.PRNGKey,
    ) -> list[
        float | jax.Array,
        float,
        int,
    ]:
        """The one-step Metropolis update

        Args:
            xs: (num_of_orbs,) the 1D coordinate of the particle(s).
                The xs are in corresponding order as in state_indices.
            state_indices: (num_of_orbs,) the array containing
                the excitations in each bath, for example,
                [0,1,2] represents there are totally 3 number
                of orbitals: ground state: 0
                            first excitation state: 1
                            second excitation state: 2
            probability:(num_of_orbs,) the probability in current particle coordiante
                xs and
                with corresponding state_indices.
            params: the flow parameter
            step_size: the step size of each sample step. e.g.
                x_new = x + step_size * jax.random.normal(subkey, shape=pos.shape)
            key: the jax PRNG key.

        Returns:
            xs_new: the updated xs
            probability_new: the updated probability
            accetp_count: the number of updates performed per walker.
        """
        key, subkey = jax.random.split(key)
        wf_vmapped = jax.vmap(self.wf_ansatz, in_axes=(None, 0, 0))

        xs_new = xs + step_size * jax.random.normal(subkey, shape=xs.shape)
        probability_new = wf_vmapped(params, xs_new, state_indices) ** 2

        # Metropolis
        key, subkey = jax.random.split(key)
        cond = (
            jax.random.uniform(subkey, shape=probability.shape)
            < probability_new / probability
        )
        probability_new = jnp.where(cond, probability_new, probability)
        xs_new = jnp.where(cond, xs_new, xs)

        # Count accepted proposals
        accept_count = jnp.sum(cond)

        return xs_new, probability_new, accept_count


def mcmc(
    steps: int,
    num_substeps: int,
    metropolis_sampler_batched: callable,
    key: jax.random.PRNGKey,
    xs_batched: jax.Array,
    state_indices: np.ndarray,
    params: dict,
    probability_batched: jax.Array,
    mc_step_size: float,
    pmove: float,
) -> list[jax.random.PRNGKey, jax.Array, jax.Array, float, float]:
    """The batched mcmc function for #steps sampling.
    NOTE: this is a jax foriloop implementation

    Args:
        steps: the steps to perform
        num_substeps: the mcmc substep number.
        metropolis_sampler_batched: the batched metropolis sampler.
        key: the jax.PRNGkey
        xs_batched: (num_of_batch,num_of_orbs,) the batched 1D coordinate
            of the particle(s).
            The xs are in corresponding order as in state_indices.
        state_indices: (num_of_orbs,)the array containing
            the excitations in each bath, for example,
            [0,1,2] represents there are totally 3 number
            of orbitals: ground state: 0
                        first excitation state: 1
                        second excitation state: 2
        params: the parameters of network
        probability_batched: (num_of_batch,num_of_orbs,)
            the batched probability for each state (wavefunction**2)
        mc_step_size: last mcmc moving step size.
        pmove: the portion of moved particles in last mcmc step.

    Returns:
        key: the jax.PRNGkey
        xs_batched: (num_of_batch,num_of_orbs,) the batched 1D
            coordinate of the particle(s).
            The xs are in corresponding order as in state_indices.
        probability_batched: (num_of_batch,num_of_orbs,)
            the batched probability for each state (wavefunction**2)
        mc_step_size: updated mcmc moving step size.
        pmove: the portion of moved particles in current mcmc step.
    """

    @jax.jit
    def _body_func(i, val):
        """MCMC Body function"""
        key, xs_batched, probability_batched, mc_step_size, pmove = val
        batch_size = xs_batched.shape[0]
        key, batch_keys = key_batch_split(key, batch_size)
        xs_batched, probability_batched, accept_count = metropolis_sampler_batched(
            xs_batched,
            state_indices,
            probability_batched,
            params,
            mc_step_size,
            batch_keys,
        )
        pmove = np.sum(accept_count) / (
            num_substeps * batch_size * state_indices.shape[0]
        )
        mc_step_size = jnp.where(
            pmove > 0.5,
            mc_step_size * 1.1,
            mc_step_size * 0.9,
        )
        return key, xs_batched, probability_batched, mc_step_size, pmove

    mcmc_init_val = (key, xs_batched, probability_batched, mc_step_size, 0)
    key, xs_batched, probability_batched, mc_step_size, pmove = jax.lax.fori_loop(
        0, steps, _body_func, mcmc_init_val
    )
    return key, xs_batched, probability_batched, mc_step_size, pmove

# %% [markdown]
# Then we initialize `batch_size` walkers, performs `thermal_step` mcmc to thermalize the system, and inspect the acceptance rate after thermalization:
#
# Hint: whilst not critical in this case, a good rule of thumb is to aim for an acceptance rate of around 50%.

# %%
def init_batched_x(
    key: jax.random.PRNGKey,
    batch_size: int,
    num_of_orbs: int,
    init_width: float = 1.0,
) -> jax.Array:
    """Init batched x

    Args:
        key: the jax PRNG key
        batch_size: the number of walkers to creat.
        num_of_orbs: the total number of orbitals.
        init_width: scale of initial Gaussian distribution

    Returns:
        init_x: (batch_size,) the initialized (batched) x.
    """
    init_x = init_width * jax.random.normal(key, shape=(batch_size, num_of_orbs),dtype=jnp.float64)
    return init_x

def key_batch_split(key: jax.random.PRNGKey, batch_size: int):
    """Like jax.random.split, but returns one subkey per batch element.

    Args:
        key: jax.PRNGkey
        batch_size: the batch size.

    Returns:
        key: jax.PRNGkey, shape (2,)
        batch_keys: jax.PRNGkeys, shape (batch_size, 2)
    """
    key, *batch_keys = jax.random.split(key, num=batch_size + 1)
    return key, jnp.asarray(batch_keys)

# %%
import time

batch_size = 100
thermal_step = 20
init_width = 1.5
step_size = 1.5
num_substeps = 1 # DONT TOUCH!

# Metropolis, thermalization
key, subkey = jax.random.split(key)
init_x_batched = init_batched_x(
    key=subkey,
    batch_size=batch_size,
    num_of_orbs=state_indices.shape[0],
    init_width=init_width,
)
metropolis = Metropolis(wf_ansatz=wf_ansatz)
metropolis_sample = metropolis.oneshot_sample
metropolis_sample_batched = jax.jit(
    jax.vmap(metropolis_sample, in_axes=(0, None, 0, None, None, 0))
)
probability_batched = (
    jax.vmap(wf_vmapped, in_axes=(None, 0, None))(
        params, init_x_batched, state_indices
    )
    ** 2
)
xs = init_x_batched

print("Thermalization...")
pmove = 0
t0 = time.time()
key, xs, probability_batched, step_size, pmove = mcmc(
    steps=thermal_step,
    num_substeps=num_substeps,
    metropolis_sampler_batched=metropolis_sample_batched,
    key=key,
    xs_batched=xs,
    state_indices=state_indices,
    params=params,
    probability_batched=probability_batched,
    mc_step_size=step_size,
    pmove=pmove,
)
t1 = time.time()
time_cost = t1 - t0
print(
    f"After Thermalization:\tpmove {pmove:.2f}\t"
    f"step_size={step_size:.4f}\ttime={time_cost:.2f}s",
    flush=True,
)
# Out:
# Thermalization...
# After Thermalization:	pmove 0.53	step_size=1.6580	time=3.69s

# %% [markdown]
# ### Optimization of the Variational Parameter
#
# Up to now we've already been able to calculate the energy expectation on our trail wavefunction!
#
# Finally it comes to find the best variational parameter $\theta_0$ that minimizes the energy expectation $E(\theta)$.
#
# With the advantages of AutoDifferentiate (AD) feature supported by Jax, the most straightforward way to find the variance minimum is to gradient descent through the paramter $\theta$.
#
# We can efficiently compute the gradient of the energy using:
#
# $$
# \nabla_\theta\mathcal{L} = 2 \mathbb{E}_{p(x)}\left[\left(E_L - \mathbb{E}_{p(x)}[E_L]\right)\nabla_\theta \log|\Psi_\theta|\right]
# $$
#
# In particular, this means we don't have to compute derivatives of the Hamiltonian, and so do not require third derivatives of the wavefunction! Code for doing so (adapted from the [FermiNet codebase](https://github.com/deepmind/ferminet)) is below.

# %%
def make_loss(
    wf_ansatz: callable, local_energy_estimator: callable, state_indices: np.ndarray
):
    """Copied from Ferminet.

    Creates the loss function, including custom gradients.
    NOTE: batched implementation!

    Args:
    wf_ansatz: function, signature (params, x, n), which evaluates wavefunction
        at a single MCMC configuration given the network parameters.
    local_energy_estimator: signature (params, xs, state_indices), here
        xs refers to the x coordinates in one single batch, xs has shape (num_of_orb,)
    state_indices: (num_of_orbs,)the array containing
        the excitations in each bath, for example,
        [0,1,2] represents there are totally 3 number
        of orbitals: ground state: 0
                    first excitation state: 1
                    second excitation state: 2
    Returns:
        total_energy: function which evaluates the both the loss as the mean of the
        local_energies, and the local energies. With custom gradients, accounting
        for derivatives in the probability distribution.
    """
    batch_local_energy = jax.vmap(
        local_energy_estimator, in_axes=(None, 0, None), out_axes=0
    )
    # FermiNet is defined in terms of the logarithm of the network, which is
    # better for numerical stability and also makes some expressions neater.
    log_wf = lambda params, x, n: jnp.log(jnp.abs(wf_ansatz(params, x, n)))
    # vmapped wavefunction: signature (params, xs, state_indices)
    log_wf_vmapped = jax.vmap(log_wf, in_axes=(None, 0, 0))
    # batch_wf: signature (params, batched_xs, state_indices)
    batch_wf = jax.vmap(log_wf_vmapped, in_axes=(None, 0, None), out_axes=0)

    @jax.custom_jvp
    def total_energy(params, batched_xs) -> tuple[float, np.ndarray]:
        """Total energy of an ensemble (batched)

        Args:
            params: the network parameters
            batched_xs: (num_of_batch, num_of_orbs,)
                the batched 1D coordinate of the particle(s).
                The xs are in corresponding order as in state_indices.

        Returns:
            loss: the total loss of the system, meaned over batch.
            e_l: (batch,num_of_orbs,) the local energy of each state.
        """
        e_l = batch_local_energy(params, batched_xs, state_indices)
        loss = jnp.mean(jnp.sum(e_l, axis=-1))
        return loss, e_l

    @total_energy.defjvp
    def total_energy_jvp(primals, tangents):
        """Custom Jacobian-vector product for unbiased local energy gradients."""
        params, batched_xs = primals
        loss, local_energy = total_energy(params, batched_xs)
        diff = local_energy - loss

        def _batch_wf(params, batched_xs):
            return batch_wf(params, batched_xs, state_indices)

        psi_primal, psi_tangent = jax.jvp(_batch_wf, primals, tangents)
        primals_out = loss, local_energy
        tangents_out = (
            jnp.mean(2 * jnp.sum(psi_tangent * diff, axis=-1)),
            local_energy,
        )

        return primals_out, tangents_out

    return total_energy

# %% [markdown]
# Then we measure the energy expection of the system we just thermalized:

# %%
# Loss function
loss_energy = make_loss(
    wf_ansatz=wf_ansatz,
    local_energy_estimator=energy_estimator.local_energy,
    state_indices=state_indices,
)
loss_and_grad = jax.jit(
    jax.value_and_grad(loss_energy, argnums=0, has_aux=True)
)
(loss, energies), gradients = loss_and_grad(params, xs)
print(f"After MCMC, with initial network, loss={loss:.5f}")
print(f"State indices: {state_indices}")
print(f"Energies = {jnp.mean(energies,axis=0)}")
# Out:
# After MCMC, with initial network, loss=35.99814
# State indices: [0 1 2]
# Energies = [ 1.07119924 10.53724865 24.38969182]

# %% [markdown]
# With the gradients calculates, we can update the variational parameters to reduce the total energy expectation.
#
# For small and simple systems, a simple first order optimization method such as ADAM is sufficient. The [`optax`](https://github.com/deepmind/optax) library provides many optimizers and useful utilities for optimization.
#
# Other optimizers in `optax` share the same API: the `init` method initialises the optimizer and takes an arbitary structure (a "PyTree") of trainable parameters. This conveniently enables parameters to be organised as nested dictionaries, for example.
#
# Now we seek for a one-step optimization using `optax`, and see if the loss after optimizaiton decreases:

# %%
import optax

init_learning_rate = 2e-2
# One Step Optimization
optimizer = optax.adam(init_learning_rate)
opt_state = optimizer.init(params)

updates, opt_state = optimizer.update(gradients, opt_state, params)
new_params = optax.apply_updates(params, updates)
(loss, energies), gradients = loss_and_grad(new_params, xs)
print(f"One step optimization with previous x, loss={loss:.5f}")
print(f"Energies = {jnp.mean(energies,axis=0)}")
# Out:
# One step optimization with previous x, loss=35.94580
# Energies = [ 1.06236943 10.525028   24.35840061]

# %% [markdown]
# > That's one small step for 'an' electron, one giant leap towards ground state

# %% [markdown]
# To reach for the variational minimum, we need to loop over the following training steps for each iteration:
#
# 1. runs Metropolis-Hastings to draw samples according to $\Psi^2$
# 2. evaluates the energy and gradients
# 3. updates the parameters
#
# Tip: Remember to equilibrate the MCMC samples after initialising them from a Gaussian distribution, as well as between each parameter update!
#
# The core training update function is implemented as:

# %%
class Update:
    """Update functions"""

    def __init__(
        self,
        mcmc_steps: int,
        state_indices: np.ndarray,
        batch_size: int,
        num_substeps: int,
        metropolis_sampler_batched: callable,
        loss_and_grad: callable,
        optimizer: optax.GradientTransformation,
        acc_steps: int,
    ) -> None:
        self.mcmc_steps = mcmc_steps
        self.state_indices = state_indices
        self.batch_size = batch_size
        self.num_substeps = num_substeps
        self.metropolis_sampler_batched = metropolis_sampler_batched
        self.loss_and_grad = loss_and_grad
        self.optimizer = optimizer
        self.acc_steps = acc_steps

    def update(
        self,
        key: jax.random.PRNGKey,
        xs_batched: jax.Array,
        probability_batched: jax.Array,
        mc_step_size: float,
        params: jax.Array | np.ndarray | dict,
        opt_state: optax.OptState,
    ) -> tuple[
        float, float, jax.Array, jax.Array, dict, optax.OptState, float, float
    ]:
        """Single update
        NOTE: call WITHOUT vmap!

        Args:
            key: the jax.PRNGkey
            xs_batched: (num_of_batch,num_of_orbs,) the batched 1D coordinate
                of the particle(s).
                The xs are in corresponding order as in state_indices.
            probability_batched: (num_of_batch,num_of_orbs,)
                the batched probability for each state (wavefunction**2)
            mc_step_size: the initial mcmc moving step size.
            params: the flow parameters
            opt_state: the optimizer state.

        Returns:
            loss: the meaned energy as loss
            energy_std: the energy standard deviation.
            xs_batched: the coordinate
            probability_batched: the batched probability (wavefunction**2)
            params: the flow parameters
            opt_state: the optimizer state.
            pmove: the portion of moved coordinates.
            mc_step_size: the mcmc moving step size.
        """

        def _mcmc_body_func(i, val):
            """MCMC Body function"""
            key, xs_batched, probability_batched, mc_step_size, pmove = val
            key, batch_keys = key_batch_split(key, self.batch_size)
            (
                xs_batched,
                probability_batched,
                accept_count,
            ) = self.metropolis_sampler_batched(
                xs_batched,
                self.state_indices,
                probability_batched,
                params,
                mc_step_size,
                batch_keys,
            )
            pmove = np.sum(accept_count) / (
                self.num_substeps * self.batch_size * self.state_indices.shape[0]
            )
            mc_step_size = jnp.where(
                pmove > 0.5,
                mc_step_size * 1.1,
                mc_step_size * 0.9,
            )
            return key, xs_batched, probability_batched, mc_step_size, pmove

        def _acc_body_func(i, val):
            """Gradient Accumulation Body Function"""
            (
                loss,
                energies,
                grad,
                key,
                xs_batched,
                probability_batched,
                mc_step_size,
                pmove,
                params,
            ) = val
            mcmc_init_val = (key, xs_batched, probability_batched, mc_step_size, 0)
            (
                key,
                xs_batched,
                probability_batched,
                mc_step_size,
                pmove,
            ) = jax.lax.fori_loop(0, self.mcmc_steps, _mcmc_body_func, mcmc_init_val)
            (loss, energies), gradients = self.loss_and_grad(params, xs_batched)
            grad = jax.tree.map(jnp.mean, gradients)
            return (
                loss,
                energies,
                grad,
                key,
                xs_batched,
                probability_batched,
                mc_step_size,
                pmove,
                params,
            )

        # Only for initialization of val in jax.lax.foriloop!
        (loss, energies), gradients = self.loss_and_grad(params, xs_batched)
        grad = jax.tree.map(jnp.mean, gradients)
        acc_init_val = (
            loss,
            energies,
            grad,
            key,
            xs_batched,
            probability_batched,
            mc_step_size,
            0,
            params,
        )

        (
            loss,
            energies,
            grad,
            key,
            xs_batched,
            probability_batched,
            mc_step_size,
            pmove,
            params,
        ) = jax.lax.fori_loop(0, self.acc_steps, _acc_body_func, acc_init_val)

        updates, opt_state = self.optimizer.update(grad, opt_state, params)
        params = optax.apply_updates(params, updates)
        energy_std = jnp.sqrt(
            ((jnp.sum(energies, axis=-1) ** 2).mean() - loss**2)
            / (self.acc_steps * self.batch_size)
        )
        return (
            loss,
            energy_std,
            xs_batched,
            probability_batched,
            params,
            opt_state,
            pmove,
            mc_step_size,
        )

# %% [markdown]
# ### Ground State (Variational)
#
# Scripts below performs a complete ground state variational calculation, with system parameters defined at the formost of the code:

# %%
import tqdm.notebook as tqdm

# %%
print("=======================GS=========================")
key = jax.random.PRNGKey(42)
# System settings
batch_size = 500
state_indices = np.arange(1)
thermal_step = 20
acc_steps = 1
mc_steps = 20
step_size = 1.5
num_substeps = 1  # DONT MOVE!
init_width = 1.5
init_learning_rate = 2e-2
iterations = 2000

# Initialize flow
model_flow = MLPFlow(out_dims=1)
key, subkey = jax.random.split(key)
x_dummy = jax.random.normal(subkey,dtype=jnp.float64)  # Dummy input data
key, subkey = jax.random.split(key)
params = model_flow.init(subkey, x_dummy)
# Initial Jacobian
init_jacobian = jax.jacfwd(lambda x: model_flow.apply(params, x))(x_dummy)
print(f"Init Jacobian = \n{init_jacobian}")

# Initialize Wavefunction
wf_ansatz_obj = WFAnsatz(flow=model_flow)
wf_ansatz = wf_ansatz_obj.wf_ansatz
wf_vmapped = jax.vmap(wf_ansatz, in_axes=(None, 0, 0))

# Plotting wavefunction
print("Wavefunction (Initialization)")
xmin = -10
xmax = 10
Nmesh = 2000
xmesh = np.linspace(xmin, xmax, Nmesh,dtype=np.float64)
mesh_interval = xmesh[1] - xmesh[0]
plt.figure()
for i in state_indices:
    wf_on_mesh = jax.vmap(wf_ansatz, in_axes=(None, 0, None))(params, xmesh, i)
    plt.plot(xmesh, wf_on_mesh, label=f"n={i}")
plt.xlim([-10, 10])
plt.legend()
plt.title("Wavefunction (Initialization)")
plt.show()
plt.close()

# Local Energy Estimator
energy_estimator = EnergyEstimator(wf_ansatz=wf_ansatz)

# Metropolis, thermalization
key, subkey = jax.random.split(key)
init_x_batched = init_batched_x(
    key=subkey,
    batch_size=batch_size,
    num_of_orbs=state_indices.shape[0],
    init_width=init_width,
)
metropolis = Metropolis(wf_ansatz=wf_ansatz)
metropolis_sample = metropolis.oneshot_sample
metropolis_sample_batched = jax.jit(
    jax.vmap(metropolis_sample, in_axes=(0, None, 0, None, None, 0))
)
probability_batched = (
    jax.vmap(wf_vmapped, in_axes=(None, 0, None))(
        params, init_x_batched, state_indices
    )
    ** 2
)
xs = init_x_batched

print("Thermalization...")
pmove = 0
t0 = time.time()
key, xs, probability_batched, step_size, pmove = mcmc(
    steps=thermal_step,
    num_substeps=num_substeps,
    metropolis_sampler_batched=metropolis_sample_batched,
    key=key,
    xs_batched=xs,
    state_indices=state_indices,
    params=params,
    probability_batched=probability_batched,
    mc_step_size=step_size,
    pmove=pmove,
)
t1 = time.time()
time_cost = t1 - t0
print(
    f"After Thermalization:\tpmove {pmove:.2f}\t"
    f"step_size={step_size:.4f}\ttime={time_cost:.2f}s",
    flush=True,
)

# Loss function
loss_energy = make_loss(
    wf_ansatz=wf_ansatz,
    local_energy_estimator=energy_estimator.local_energy,
    state_indices=state_indices,
)
loss_and_grad = jax.jit(
    jax.value_and_grad(loss_energy, argnums=0, has_aux=True)
)
(loss, energies), gradients = loss_and_grad(params, xs)
print(f"After MCMC, with initial network, loss={loss:.2f}")

# One Step Optimization
optimizer = optax.adam(init_learning_rate)
opt_state = optimizer.init(params)

# Update
update_obj = Update(
    mcmc_steps=mc_steps,
    state_indices=state_indices,
    batch_size=batch_size,
    num_substeps=num_substeps,
    metropolis_sampler_batched=metropolis_sample_batched,
    loss_and_grad=loss_and_grad,
    optimizer=optimizer,
    acc_steps=acc_steps,
)
update = jax.jit(update_obj.update)
loss_energy_list = []
energy_std_list = []
for i in tqdm.tqdm(range(iterations)):
    t0 = time.time()
    key, subkey = jax.random.split(key)
    (
        loss_energy,
        energy_std,
        xs,
        probability_batched,
        params,
        opt_state,
        pmove,
        step_size,
    ) = update(
        subkey,
        xs,
        probability_batched,
        step_size,
        params,
        opt_state,
    )
    t1 = time.time()
    print(
        f"Iter:{i}, LossE={loss_energy:.5f}({energy_std:.5f})",
        f"\t pmove={pmove:.2f}\tstepsize={step_size:.4f}",
        f"\t time={(t1-t0):.2f}s",
        end="\r",
        flush=True,
    )
    loss_energy_list.append(loss_energy)
    energy_std_list.append(energy_std)

expectedenergy = 0.194
plot_step = 10
plt.figure()
plt.errorbar(
    range(iterations)[::plot_step],
    loss_energy_list[::plot_step],
    energy_std_list[::plot_step],
    label="loss",
    fmt="o",
    markersize=1,
    capsize=0.4,
    elinewidth=0.3,
    linestyle="none",
)
plt.plot([0, iterations], [expectedenergy, expectedenergy], label="ref")
plt.xlabel("Epoch")
plt.ylabel("Loss,E")
plt.xscale("log")
plt.legend()
plt.show()
plt.close()

# Finally Plotting Probability Density
print("Probability Density (Trained)")
plt.figure()
for i in state_indices:
    wf_on_mesh = jax.vmap(wf_ansatz, in_axes=(None, 0, None))(params, xmesh, i)
    normalize_factor = (wf_on_mesh**2).sum() * mesh_interval
    prob_density = wf_on_mesh**2 / normalize_factor
    plt.plot(xmesh, prob_density, label="VMC", lw=2)
plt.xlim([-1.5, 1.5])
plt.legend()
plt.ylabel(r"$\rho$")
plt.title("Probability Density (Trained)")
plt.show()
plt.close()

# Calculate last 100 epochs' energy
last_energies = loss_energy_list[-100::]
last_std = energy_std_list[-100::]
energy_final = np.mean(last_energies)
std_final = np.mean(last_std)
print(f"After training, get energy = {energy_final:.5f}({std_final:.5f})")

print("=======================GS=========================")
# Out:
# =======================GS=========================
# Init Jacobian =
# [0.99484643]
# Wavefunction (Initialization)
# Thermalization...
# After Thermalization:	pmove 0.46	step_size=1.3566	time=4.08s
# After MCMC, with initial network, loss=1.08
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Iter:1999, LossE=0.18595(0.00574) 	 pmove=0.44	stepsize=1.1848 	 time=0.00s	 pmove=0.47	stepsize=0.9439 	 time=0.00s 	 pmove=0.53	stepsize=1.3543 	 time=0.00s 	 pmove=0.52	stepsize=1.3087 	 time=0.00s 	 pmove=0.51	stepsize=1.2934 	 time=0.00s 	 pmove=0.47	stepsize=1.1650 	 time=0.00s 	 pmove=0.47	stepsize=1.1619 	 time=0.00s 	 pmove=0.50	stepsize=0.9678 	 time=0.00s 	 pmove=0.52	stepsize=1.2715 	 time=0.00s 	 pmove=0.52	stepsize=1.2579 	 time=0.00s 	 pmove=0.50	stepsize=1.2528 	 time=0.00s 	 pmove=0.48	stepsize=1.1164 	 time=0.00s 	 pmove=0.54	stepsize=1.1093 	 time=0.00s 	 pmove=0.49	stepsize=1.0853 	 time=0.00s 	 pmove=0.42	stepsize=1.1997 	 time=0.00s
# Probability Density (Trained)
# After training, get energy = 0.19544(0.00683)
# =======================GS=========================

# %% [markdown]
# ### Excited States (Variational)

# %%
key = jax.random.PRNGKey(42)
num_of_excitation_orbs = 2
print("======================================")
print(f"First {num_of_excitation_orbs} Excitation States")
print("======================================")
# System settings
batch_size = 500
inference_batch_size = 1000
state_indices = np.arange(num_of_excitation_orbs)
thermal_step = 20
inference_thermal_step = 50
acc_steps = 1
mc_steps = 50
step_size = 1.5
num_substeps = 1  # DONT MOVE!
init_width = 1.5
init_learning_rate = 2e-2
iterations = 2000

# Initialize flow
model_flow = MLPFlow(out_dims=1)
key, subkey = jax.random.split(key)
x_dummy = jnp.array(-1.0,dtype=jnp.float64)
key, subkey = jax.random.split(key)
params = model_flow.init(subkey, x_dummy)
# Initial Jacobian
init_jacobian = jax.jacfwd(lambda x: model_flow.apply(params, x))(x_dummy)
print(f"Init Jacobian = \n{init_jacobian}")

# Initialize Wavefunction
wf_ansatz_obj = WFAnsatz(flow=model_flow)
wf_ansatz = wf_ansatz_obj.wf_ansatz
wf_vmapped = jax.vmap(wf_ansatz, in_axes=(None, 0, 0))

# Plotting wavefunction
print("Wavefunction (Initialization)")
xmin = -10
xmax = 10
Nmesh = 2000
xmesh = np.linspace(xmin, xmax, Nmesh,dtype=np.float64)
mesh_interval = xmesh[1] - xmesh[0]
plt.figure()
for i in state_indices:
    wf_on_mesh = jax.vmap(wf_ansatz, in_axes=(None, 0, None))(params, xmesh, i)
    plt.plot(xmesh, wf_on_mesh, label=f"n={i}")
plt.xlim([-10, 10])
plt.legend()
plt.title("Wavefunction (Initialization)")
plt.show()
plt.close()

# Local Energy Estimator
energy_estimator = EnergyEstimator(wf_ansatz=wf_ansatz)

# Metropolis, thermalization
key, subkey = jax.random.split(key)
init_x_batched = init_batched_x(
    key=subkey,
    batch_size=batch_size,
    num_of_orbs=state_indices.shape[0],
    init_width=init_width,
)
metropolis = Metropolis(wf_ansatz=wf_ansatz)
metropolis_sample = metropolis.oneshot_sample
metropolis_sample_batched = jax.jit(
    jax.vmap(metropolis_sample, in_axes=(0, None, 0, None, None, 0))
)
probability_batched = (
    jax.vmap(wf_vmapped, in_axes=(None, 0, None))(
        params, init_x_batched, state_indices
    )
    ** 2
)
xs = init_x_batched

print("Thermalization...")
pmove = 0
t0 = time.time()
key, xs, probability_batched, step_size, pmove = mcmc(
    steps=thermal_step,
    num_substeps=num_substeps,
    metropolis_sampler_batched=metropolis_sample_batched,
    key=key,
    xs_batched=xs,
    state_indices=state_indices,
    params=params,
    probability_batched=probability_batched,
    mc_step_size=step_size,
    pmove=pmove,
)
t1 = time.time()
time_cost = t1 - t0
print(
    f"After Thermalization:\tpmove {pmove:.2f}\t"
    f"step_size={step_size:.4f}\ttime={time_cost:.2f}s",
    flush=True,
)

# Loss function
loss_energy = make_loss(
    wf_ansatz=wf_ansatz,
    local_energy_estimator=energy_estimator.local_energy,
    state_indices=state_indices,
)
loss_and_grad = jax.jit(
    jax.value_and_grad(loss_energy, argnums=0, has_aux=True)
)
(loss, energies), gradients = loss_and_grad(params, xs)
print(f"After MCMC, with initial network, loss={loss:.2f}")

# Optimizer
optimizer = optax.adam(init_learning_rate)
opt_state = optimizer.init(params)

# Training
update_obj = Update(
    mcmc_steps=mc_steps,
    state_indices=state_indices,
    batch_size=batch_size,
    num_substeps=num_substeps,
    metropolis_sampler_batched=metropolis_sample_batched,
    loss_and_grad=loss_and_grad,
    optimizer=optimizer,
    acc_steps=acc_steps,
)
update = jax.jit(update_obj.update)
loss_energy_list = []
energy_std_list = []
for i in tqdm.tqdm(range(iterations)):
    t0 = time.time()
    key, subkey = jax.random.split(key)
    (
        loss_energy,
        energy_std,
        xs,
        probability_batched,
        params,
        opt_state,
        pmove,
        step_size,
    ) = update(
        subkey,
        xs,
        probability_batched,
        step_size,
        params,
        opt_state,
    )
    t1 = time.time()
    print(
        f"Iter:{i}, LossE={loss_energy:.5f}({energy_std:.5f})"
        f"\t pmove={pmove:.2f}\tstepsize={step_size:.4f}"
        f"\t time={(t1-t0):.2f}s"
    )
    loss_energy_list.append(loss_energy)
    energy_std_list.append(energy_std)

# Training Curve
plot_step = 10
plt.figure()
plt.errorbar(
    range(iterations)[::plot_step],
    loss_energy_list[::plot_step],
    energy_std_list[::plot_step],
    label="loss",
    fmt="o",
    markersize=1,
    capsize=0.4,
    elinewidth=0.3,
    linestyle="none",
)
plt.xlabel("Epoch")
plt.ylabel("Loss,E")
plt.xscale("log")
plt.legend()
plt.show()
plt.close()

# Inference
print("...Inferencing...")
key, subkey = jax.random.split(key)
xs_inference = init_batched_x(
    key=subkey,
    batch_size=inference_batch_size,
    num_of_orbs=state_indices.shape[0],
    init_width=init_width,
)
probability_batched = (
    jax.vmap(wf_vmapped, in_axes=(None, 0, None))(
        params, xs_inference, state_indices
    )
    ** 2
)
print("Thermalization...")
t0 = time.time()
key, xs_inference, probability_batched, step_size, pmove = mcmc(
    steps=inference_thermal_step,
    num_substeps=num_substeps,
    metropolis_sampler_batched=metropolis_sample_batched,
    key=key,
    xs_batched=xs_inference,
    state_indices=state_indices,
    params=params,
    probability_batched=probability_batched,
    mc_step_size=step_size,
    pmove=pmove,
)
t1 = time.time()
time_cost = t1 - t0
print(
    f"After Thermalization:\tpmove {pmove:.2f}\t"
    f"step_size={step_size:.4f}\ttime={time_cost:.2f}s",
    flush=True,
)

print("Mesuring Energy...")
(_, energies_batched), _ = loss_and_grad(params, xs_inference)
energy_levels = jnp.mean(energies_batched, axis=0)
energy_levels_std = jnp.sqrt(
    (jnp.mean(energies_batched**2, axis=0) - energy_levels**2)
    / (acc_steps * batch_size)
)

for i, energyi in enumerate(energy_levels):
    print(f"n={i}\tenergy={energyi:.5f}({energy_levels_std[i]:.5f})")

print("======================================")
print("Excitation States")
print("======================================")
# Out:
# ======================================
# First 2 Excitation States
# ======================================
# Init Jacobian =
# [0.99310585]
# Wavefunction (Initialization)
# Thermalization...
# After Thermalization:	pmove 0.53	step_size=1.3566	time=4.17s
# After MCMC, with initial network, loss=7.80
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Iter:0, LossE=9.22891(0.70397)	 pmove=0.48	stepsize=1.2897	 time=11.31s
# Iter:1, LossE=8.11520(0.65760)	 pmove=0.54	stepsize=1.4985	 time=0.11s
# Iter:2, LossE=8.95505(0.78878)	 pmove=0.52	stepsize=1.4246	 time=0.11s
# Iter:3, LossE=9.46133(0.82958)	 pmove=0.45	stepsize=1.3543	 time=0.11s
# Iter:4, LossE=7.79889(0.75979)	 pmove=0.52	stepsize=1.5736	 time=0.09s
# Iter:5, LossE=7.26419(0.53109)	 pmove=0.51	stepsize=1.4960	 time=0.11s
# Iter:6, LossE=7.48935(0.66646)	 pmove=0.54	stepsize=1.4222	 time=0.11s
# Iter:7, LossE=8.91747(0.81553)	 pmove=0.50	stepsize=1.3520	 time=0.12s
# Iter:8, LossE=8.10997(0.63856)	 pmove=0.51	stepsize=1.5710	 time=0.11s
# Iter:9, LossE=7.74611(0.70738)	 pmove=0.49	stepsize=1.2219	 time=0.11s
# Iter:10, LossE=8.50882(0.97912)	 pmove=0.52	stepsize=1.4198	 time=0.11s
# Iter:11, LossE=6.46003(0.54805)	 pmove=0.48	stepsize=1.3498	 time=0.11s
# Iter:12, LossE=7.11292(0.67363)	 pmove=0.47	stepsize=1.2832	 time=0.11s
# Iter:13, LossE=7.84587(0.71873)	 pmove=0.52	stepsize=1.4910	 time=0.12s
# Iter:14, LossE=7.18826(0.57460)	 pmove=0.52	stepsize=1.4174	 time=0.11s
# Iter:15, LossE=8.16654(0.94994)	 pmove=0.52	stepsize=1.3475	 time=0.11s
# Iter:16, LossE=6.42290(0.54075)	 pmove=0.47	stepsize=1.2810	 time=0.12s
# Iter:17, LossE=6.74819(0.61430)	 pmove=0.51	stepsize=1.4885	 time=0.11s
# Iter:18, LossE=6.44923(0.54195)	 pmove=0.50	stepsize=1.1577	 time=0.11s
# Iter:19, LossE=9.39673(0.82839)	 pmove=0.48	stepsize=1.3452	 time=0.10s
# Iter:20, LossE=6.58361(0.61090)	 pmove=0.49	stepsize=1.2789	 time=0.11s
# Iter:21, LossE=5.88121(0.49351)	 pmove=0.50	stepsize=1.2158	 time=0.12s
# Iter:22, LossE=6.20501(0.57196)	 pmove=0.51	stepsize=1.4127	 time=0.11s
# Iter:23, LossE=6.34959(0.55081)	 pmove=0.53	stepsize=1.3430	 time=0.11s
# Iter:24, LossE=7.09150(0.72615)	 pmove=0.49	stepsize=1.2767	 time=0.11s
# Iter:25, LossE=6.09408(0.49473)	 pmove=0.50	stepsize=1.4835	 time=0.12s
# Iter:26, LossE=5.88181(0.58917)	 pmove=0.54	stepsize=1.4103	 time=0.11s
# Iter:27, LossE=6.44744(0.80220)	 pmove=0.50	stepsize=1.0969	 time=0.12s
# Iter:28, LossE=5.31064(0.42153)	 pmove=0.55	stepsize=1.2746	 time=0.11s
# Iter:29, LossE=5.35395(0.43043)	 pmove=0.48	stepsize=1.2117	 time=0.12s
# Iter:30, LossE=4.94822(0.36317)	 pmove=0.54	stepsize=1.4079	 time=0.11s
# Iter:31, LossE=5.73310(0.45143)	 pmove=0.55	stepsize=1.3385	 time=0.11s
# Iter:32, LossE=5.76364(0.47968)	 pmove=0.51	stepsize=1.2724	 time=0.11s
# Iter:33, LossE=5.00037(0.42941)	 pmove=0.54	stepsize=1.2097	 time=0.11s
# Iter:34, LossE=4.73570(0.35545)	 pmove=0.50	stepsize=1.4055	 time=0.11s
# Iter:35, LossE=5.11327(0.46228)	 pmove=0.51	stepsize=1.3362	 time=0.11s
# Iter:36, LossE=6.52046(0.70789)	 pmove=0.53	stepsize=1.2703	 time=0.11s
# Iter:37, LossE=5.00541(0.45930)	 pmove=0.53	stepsize=1.2076	 time=0.12s
# Iter:38, LossE=4.51794(0.38213)	 pmove=0.48	stepsize=1.1481	 time=0.11s
# Iter:39, LossE=5.22353(0.53691)	 pmove=0.51	stepsize=1.3340	 time=0.11s
# Iter:40, LossE=5.36710(0.66566)	 pmove=0.52	stepsize=1.2682	 time=0.11s
# Iter:41, LossE=4.56318(0.45824)	 pmove=0.52	stepsize=1.2056	 time=0.12s
# Iter:42, LossE=4.60861(0.42169)	 pmove=0.48	stepsize=1.1461	 time=0.11s
# Iter:43, LossE=4.94990(0.49897)	 pmove=0.48	stepsize=1.0896	 time=0.12s
# Iter:44, LossE=4.26325(0.42776)	 pmove=0.51	stepsize=1.2660	 time=0.11s
# Iter:45, LossE=4.13704(0.41275)	 pmove=0.52	stepsize=1.2036	 time=0.11s
# Iter:46, LossE=3.65679(0.35204)	 pmove=0.48	stepsize=1.1442	 time=0.11s
# Iter:47, LossE=3.44704(0.23414)	 pmove=0.49	stepsize=1.0878	 time=0.12s
# Iter:48, LossE=3.87622(0.33559)	 pmove=0.50	stepsize=1.2639	 time=0.11s
# Iter:49, LossE=3.50270(0.26640)	 pmove=0.53	stepsize=1.2016	 time=0.12s
# Iter:50, LossE=3.58546(0.31548)	 pmove=0.48	stepsize=1.1423	 time=0.10s
# Iter:51, LossE=3.40531(0.29791)	 pmove=0.46	stepsize=1.0859	 time=0.11s
# Iter:52, LossE=3.46631(0.29426)	 pmove=0.51	stepsize=1.2618	 time=0.12s
# Iter:53, LossE=3.46124(0.25742)	 pmove=0.53	stepsize=1.1995	 time=0.11s
# Iter:54, LossE=4.10474(0.41679)	 pmove=0.51	stepsize=1.1404	 time=0.11s
# Iter:55, LossE=3.18284(0.27276)	 pmove=0.49	stepsize=1.0841	 time=0.12s
# Iter:56, LossE=3.47277(0.37526)	 pmove=0.57	stepsize=1.0306	 time=0.11s
# Iter:57, LossE=2.78253(0.19344)	 pmove=0.49	stepsize=0.9798	 time=0.11s
# Iter:58, LossE=3.12011(0.30452)	 pmove=0.54	stepsize=1.1385	 time=0.12s
# Iter:59, LossE=2.96036(0.20274)	 pmove=0.54	stepsize=1.0823	 time=0.12s
# Iter:60, LossE=2.95977(0.20413)	 pmove=0.49	stepsize=1.0289	 time=0.12s
# Iter:61, LossE=3.60470(0.37810)	 pmove=0.49	stepsize=0.9782	 time=0.11s
# Iter:62, LossE=2.81589(0.22662)	 pmove=0.49	stepsize=0.9299	 time=0.11s
# Iter:63, LossE=2.66422(0.20678)	 pmove=0.49	stepsize=0.8840	 time=0.12s
# Iter:64, LossE=2.64948(0.22671)	 pmove=0.49	stepsize=1.0272	 time=0.11s
# Iter:65, LossE=2.63143(0.17456)	 pmove=0.54	stepsize=0.9765	 time=0.10s
# Iter:66, LossE=2.76179(0.18722)	 pmove=0.49	stepsize=0.9283	 time=0.12s
# Iter:67, LossE=2.59222(0.17138)	 pmove=0.45	stepsize=1.0787	 time=0.12s
# Iter:68, LossE=2.70031(0.14849)	 pmove=0.55	stepsize=1.0255	 time=0.12s
# Iter:69, LossE=2.62666(0.18342)	 pmove=0.49	stepsize=0.9749	 time=0.11s
# Iter:70, LossE=2.50144(0.13041)	 pmove=0.49	stepsize=0.9268	 time=0.11s
# Iter:71, LossE=3.06972(0.23097)	 pmove=0.50	stepsize=0.8811	 time=0.12s
# Iter:72, LossE=2.46131(0.14092)	 pmove=0.51	stepsize=1.0237	 time=0.12s
# Iter:73, LossE=2.90578(0.21499)	 pmove=0.52	stepsize=0.9732	 time=0.11s
# Iter:74, LossE=2.70518(0.19382)	 pmove=0.52	stepsize=0.9252	 time=0.12s
# Iter:75, LossE=2.64625(0.15499)	 pmove=0.50	stepsize=1.0751	 time=0.12s
# Iter:76, LossE=2.71092(0.13290)	 pmove=0.51	stepsize=1.0220	 time=0.11s
# Iter:77, LossE=2.80083(0.26399)	 pmove=0.48	stepsize=0.9716	 time=0.12s
# Iter:78, LossE=2.70717(0.18862)	 pmove=0.54	stepsize=0.9237	 time=0.11s
# Iter:79, LossE=2.85699(0.18883)	 pmove=0.49	stepsize=0.8781	 time=0.11s
# Iter:80, LossE=2.55372(0.20047)	 pmove=0.49	stepsize=0.8348	 time=0.09s
# Iter:81, LossE=2.46195(0.11041)	 pmove=0.51	stepsize=0.9700	 time=0.11s
# Iter:82, LossE=2.54908(0.12410)	 pmove=0.53	stepsize=0.9221	 time=0.11s
# Iter:83, LossE=2.67039(0.16524)	 pmove=0.51	stepsize=1.0714	 time=0.12s
# Iter:84, LossE=2.77354(0.17778)	 pmove=0.54	stepsize=0.8334	 time=0.11s
# Iter:85, LossE=2.52212(0.14291)	 pmove=0.48	stepsize=0.7923	 time=0.12s
# Iter:86, LossE=2.62402(0.15821)	 pmove=0.52	stepsize=0.9206	 time=0.11s
# Iter:87, LossE=2.85515(0.20768)	 pmove=0.47	stepsize=0.8752	 time=0.11s
# Iter:88, LossE=2.48533(0.15564)	 pmove=0.48	stepsize=0.8320	 time=0.11s
# Iter:89, LossE=2.62077(0.11963)	 pmove=0.50	stepsize=0.9667	 time=0.12s
# Iter:90, LossE=2.69529(0.12778)	 pmove=0.47	stepsize=0.9190	 time=0.11s
# Iter:91, LossE=2.40551(0.11833)	 pmove=0.48	stepsize=0.8737	 time=0.11s
# Iter:92, LossE=2.87714(0.19043)	 pmove=0.49	stepsize=0.8306	 time=0.11s
# Iter:93, LossE=2.50024(0.13758)	 pmove=0.53	stepsize=0.9651	 time=0.11s
# Iter:94, LossE=2.77724(0.17086)	 pmove=0.55	stepsize=0.9175	 time=0.12s
# Iter:95, LossE=2.58536(0.10903)	 pmove=0.53	stepsize=1.0661	 time=0.12s
# Iter:96, LossE=2.25394(0.11984)	 pmove=0.49	stepsize=0.8292	 time=0.10s
# Iter:97, LossE=2.57505(0.11797)	 pmove=0.48	stepsize=0.7883	 time=0.12s
# Iter:98, LossE=2.64337(0.12297)	 pmove=0.54	stepsize=0.9159	 time=0.11s
# Iter:99, LossE=2.59619(0.13485)	 pmove=0.51	stepsize=1.0643	 time=0.11s
# Iter:100, LossE=2.60914(0.15834)	 pmove=0.51	stepsize=1.0118	 time=0.11s
# Iter:101, LossE=2.18612(0.08755)	 pmove=0.52	stepsize=0.9619	 time=0.11s
# Iter:102, LossE=2.47547(0.10805)	 pmove=0.47	stepsize=0.9144	 time=0.11s
# Iter:103, LossE=2.39227(0.10032)	 pmove=0.48	stepsize=0.8693	 time=0.12s
# Iter:104, LossE=2.24540(0.09079)	 pmove=0.45	stepsize=1.0101	 time=0.11s
# Iter:105, LossE=2.75612(0.14029)	 pmove=0.46	stepsize=0.9602	 time=0.12s
# Iter:106, LossE=2.50544(0.13326)	 pmove=0.49	stepsize=0.9129	 time=0.12s
# Iter:107, LossE=2.57986(0.22225)	 pmove=0.48	stepsize=0.8678	 time=0.12s
# Iter:108, LossE=2.40142(0.13048)	 pmove=0.51	stepsize=1.0084	 time=0.11s
# Iter:109, LossE=2.36920(0.13216)	 pmove=0.45	stepsize=0.9586	 time=0.12s
# Iter:110, LossE=2.46478(0.12394)	 pmove=0.51	stepsize=1.1139	 time=0.11s
# Iter:111, LossE=2.31184(0.12432)	 pmove=0.49	stepsize=0.8664	 time=0.10s
# Iter:112, LossE=2.53559(0.14325)	 pmove=0.48	stepsize=0.8236	 time=0.11s
# Iter:113, LossE=2.42814(0.12530)	 pmove=0.52	stepsize=0.9570	 time=0.12s
# Iter:114, LossE=2.35155(0.11781)	 pmove=0.49	stepsize=0.9098	 time=0.11s
# Iter:115, LossE=2.67531(0.16878)	 pmove=0.51	stepsize=1.0571	 time=0.12s
# Iter:116, LossE=2.69077(0.19213)	 pmove=0.52	stepsize=1.0050	 time=0.11s
# Iter:117, LossE=2.80316(0.19276)	 pmove=0.51	stepsize=0.9554	 time=0.12s
# Iter:118, LossE=2.55271(0.14545)	 pmove=0.48	stepsize=0.9083	 time=0.11s
# Iter:119, LossE=2.59900(0.22032)	 pmove=0.49	stepsize=0.8635	 time=0.12s
# Iter:120, LossE=2.33263(0.10804)	 pmove=0.53	stepsize=1.0033	 time=0.11s
# Iter:121, LossE=2.28614(0.09696)	 pmove=0.53	stepsize=0.9538	 time=0.11s
# Iter:122, LossE=2.37548(0.12704)	 pmove=0.52	stepsize=1.1083	 time=0.12s
# Iter:123, LossE=2.25236(0.09574)	 pmove=0.51	stepsize=1.0536	 time=0.12s
# Iter:124, LossE=2.49756(0.12838)	 pmove=0.52	stepsize=1.0016	 time=0.12s
# Iter:125, LossE=2.44008(0.15761)	 pmove=0.51	stepsize=0.9522	 time=0.11s
# Iter:126, LossE=2.44617(0.12812)	 pmove=0.49	stepsize=0.9052	 time=0.10s
# Iter:127, LossE=2.26769(0.11472)	 pmove=0.50	stepsize=0.8606	 time=0.12s
# Iter:128, LossE=2.58312(0.15034)	 pmove=0.50	stepsize=0.9999	 time=0.11s
# Iter:129, LossE=2.30054(0.13496)	 pmove=0.48	stepsize=0.9506	 time=0.12s
# Iter:130, LossE=2.62238(0.15355)	 pmove=0.47	stepsize=0.9037	 time=0.12s
# Iter:131, LossE=2.41982(0.14250)	 pmove=0.53	stepsize=1.0501	 time=0.11s
# Iter:132, LossE=2.40407(0.13980)	 pmove=0.46	stepsize=0.9983	 time=0.11s
# Iter:133, LossE=2.53986(0.25764)	 pmove=0.48	stepsize=0.9490	 time=0.12s
# Iter:134, LossE=2.43038(0.11819)	 pmove=0.45	stepsize=0.9022	 time=0.11s
# Iter:135, LossE=2.28938(0.10154)	 pmove=0.52	stepsize=1.0483	 time=0.11s
# Iter:136, LossE=2.31165(0.10479)	 pmove=0.47	stepsize=0.9966	 time=0.11s
# Iter:137, LossE=2.30402(0.17156)	 pmove=0.53	stepsize=0.9474	 time=0.12s
# Iter:138, LossE=2.51884(0.13078)	 pmove=0.47	stepsize=0.9007	 time=0.12s
# Iter:139, LossE=2.16254(0.08731)	 pmove=0.53	stepsize=1.0465	 time=0.11s
# Iter:140, LossE=2.44874(0.12400)	 pmove=0.52	stepsize=0.9949	 time=0.12s
# Iter:141, LossE=2.23365(0.09054)	 pmove=0.55	stepsize=0.9458	 time=0.11s
# Iter:142, LossE=2.79045(0.40515)	 pmove=0.54	stepsize=0.8992	 time=0.10s
# Iter:143, LossE=2.49443(0.12470)	 pmove=0.50	stepsize=0.8548	 time=0.11s
# Iter:144, LossE=2.32956(0.15274)	 pmove=0.50	stepsize=0.8127	 time=0.11s
# Iter:145, LossE=2.38346(0.11268)	 pmove=0.46	stepsize=0.9442	 time=0.12s
# Iter:146, LossE=2.69230(0.24826)	 pmove=0.48	stepsize=0.8977	 time=0.11s
# Iter:147, LossE=2.11614(0.07640)	 pmove=0.43	stepsize=1.0430	 time=0.12s
# Iter:148, LossE=2.54032(0.19923)	 pmove=0.52	stepsize=0.9916	 time=0.11s
# Iter:149, LossE=2.45128(0.10609)	 pmove=0.51	stepsize=0.9427	 time=0.11s
# Iter:150, LossE=2.44541(0.10499)	 pmove=0.54	stepsize=0.8962	 time=0.11s
# Iter:151, LossE=2.28105(0.12457)	 pmove=0.55	stepsize=0.8520	 time=0.11s
# Iter:152, LossE=2.24167(0.08849)	 pmove=0.52	stepsize=0.9899	 time=0.11s
# Iter:153, LossE=2.43906(0.10796)	 pmove=0.51	stepsize=0.9411	 time=0.12s
# Iter:154, LossE=2.37090(0.18232)	 pmove=0.49	stepsize=0.8947	 time=0.11s
# Iter:155, LossE=2.29913(0.10768)	 pmove=0.48	stepsize=0.8505	 time=0.11s
# Iter:156, LossE=2.61882(0.14318)	 pmove=0.56	stepsize=0.9882	 time=0.11s
# Iter:157, LossE=2.31842(0.10022)	 pmove=0.46	stepsize=0.9395	 time=0.10s
# Iter:158, LossE=2.28714(0.09845)	 pmove=0.52	stepsize=0.8932	 time=0.12s
# Iter:159, LossE=2.22882(0.07761)	 pmove=0.52	stepsize=1.0378	 time=0.11s
# Iter:160, LossE=2.54311(0.11747)	 pmove=0.51	stepsize=0.9866	 time=0.11s
# Iter:161, LossE=2.32774(0.09737)	 pmove=0.50	stepsize=1.1463	 time=0.12s
# Iter:162, LossE=2.26384(0.09123)	 pmove=0.48	stepsize=0.8917	 time=0.12s
# Iter:163, LossE=2.55202(0.31676)	 pmove=0.50	stepsize=0.8477	 time=0.11s
# Iter:164, LossE=2.23100(0.09466)	 pmove=0.52	stepsize=0.9849	 time=0.12s
# Iter:165, LossE=2.50949(0.12662)	 pmove=0.52	stepsize=0.9363	 time=0.11s
# Iter:166, LossE=2.29935(0.08962)	 pmove=0.50	stepsize=1.0880	 time=0.11s
# Iter:167, LossE=2.55908(0.12427)	 pmove=0.51	stepsize=1.0343	 time=0.11s
# Iter:168, LossE=2.37725(0.09950)	 pmove=0.51	stepsize=0.9833	 time=0.12s
# Iter:169, LossE=2.23323(0.11947)	 pmove=0.47	stepsize=0.9348	 time=0.12s
# Iter:170, LossE=2.32020(0.10242)	 pmove=0.50	stepsize=1.0861	 time=0.12s
# Iter:171, LossE=2.32019(0.08388)	 pmove=0.52	stepsize=1.0326	 time=0.11s
# Iter:172, LossE=2.44648(0.12081)	 pmove=0.53	stepsize=0.9816	 time=0.09s
# Iter:173, LossE=2.33431(0.09186)	 pmove=0.52	stepsize=0.9332	 time=0.11s
# Iter:174, LossE=2.32809(0.08877)	 pmove=0.54	stepsize=0.8872	 time=0.11s
# Iter:175, LossE=2.35754(0.11534)	 pmove=0.50	stepsize=1.0308	 time=0.11s
# Iter:176, LossE=2.24264(0.08074)	 pmove=0.54	stepsize=0.9800	 time=0.11s
# Iter:177, LossE=2.30166(0.13231)	 pmove=0.44	stepsize=0.9316	 time=0.11s
# Iter:178, LossE=2.45141(0.19741)	 pmove=0.48	stepsize=0.8857	 time=0.11s
# Iter:179, LossE=2.37776(0.10306)	 pmove=0.49	stepsize=0.8420	 time=0.12s
# Iter:180, LossE=2.32533(0.15185)	 pmove=0.52	stepsize=0.9783	 time=0.11s
# Iter:181, LossE=2.46758(0.09607)	 pmove=0.53	stepsize=0.9301	 time=0.12s
# Iter:182, LossE=2.19260(0.08527)	 pmove=0.54	stepsize=0.8842	 time=0.11s
# Iter:183, LossE=2.41519(0.12778)	 pmove=0.52	stepsize=1.0274	 time=0.11s
# Iter:184, LossE=2.43739(0.14282)	 pmove=0.50	stepsize=0.9767	 time=0.11s
# Iter:185, LossE=2.45420(0.13683)	 pmove=0.51	stepsize=0.9285	 time=0.11s
# Iter:186, LossE=2.32582(0.10759)	 pmove=0.49	stepsize=0.8827	 time=0.11s
# Iter:187, LossE=2.23504(0.08054)	 pmove=0.51	stepsize=1.0256	 time=0.11s
# Iter:188, LossE=2.50286(0.18751)	 pmove=0.51	stepsize=0.9751	 time=0.10s
# Iter:189, LossE=2.30119(0.12868)	 pmove=0.49	stepsize=0.9270	 time=0.11s
# Iter:190, LossE=2.20495(0.09355)	 pmove=0.51	stepsize=1.0771	 time=0.11s
# Iter:191, LossE=2.54680(0.15244)	 pmove=0.55	stepsize=0.8378	 time=0.11s
# Iter:192, LossE=2.28290(0.07961)	 pmove=0.53	stepsize=0.9734	 time=0.11s
# Iter:193, LossE=2.37616(0.10204)	 pmove=0.52	stepsize=0.9254	 time=0.11s
# Iter:194, LossE=2.21927(0.08963)	 pmove=0.50	stepsize=0.8798	 time=0.11s
# Iter:195, LossE=2.19985(0.07459)	 pmove=0.49	stepsize=0.8364	 time=0.11s
# Iter:196, LossE=2.10767(0.09105)	 pmove=0.50	stepsize=0.9718	 time=0.11s
# Iter:197, LossE=2.26410(0.07422)	 pmove=0.52	stepsize=0.9238	 time=0.12s
# Iter:198, LossE=2.16194(0.10464)	 pmove=0.48	stepsize=0.8783	 time=0.11s
# Iter:199, LossE=2.35763(0.13489)	 pmove=0.45	stepsize=1.0205	 time=0.11s
# Iter:200, LossE=2.27861(0.08557)	 pmove=0.51	stepsize=0.9702	 time=0.11s
# Iter:201, LossE=2.58426(0.15976)	 pmove=0.48	stepsize=0.9223	 time=0.11s
# Iter:202, LossE=2.40251(0.19536)	 pmove=0.48	stepsize=0.8768	 time=0.11s
# Iter:203, LossE=2.30751(0.06711)	 pmove=0.53	stepsize=1.0188	 time=0.10s
# Iter:204, LossE=2.31817(0.12653)	 pmove=0.49	stepsize=0.7924	 time=0.11s
# Iter:205, LossE=2.18827(0.08583)	 pmove=0.45	stepsize=0.9207	 time=0.11s
# Iter:206, LossE=2.24151(0.08513)	 pmove=0.47	stepsize=0.8753	 time=0.11s
# Iter:207, LossE=2.32283(0.08054)	 pmove=0.48	stepsize=0.8321	 time=0.11s
# Iter:208, LossE=2.44763(0.12425)	 pmove=0.55	stepsize=0.9669	 time=0.11s
# Iter:209, LossE=2.12727(0.06896)	 pmove=0.54	stepsize=0.9192	 time=0.11s
# Iter:210, LossE=2.28948(0.10516)	 pmove=0.49	stepsize=0.8739	 time=0.11s
# Iter:211, LossE=2.18166(0.08080)	 pmove=0.52	stepsize=1.0154	 time=0.11s
# Iter:212, LossE=2.43502(0.13948)	 pmove=0.52	stepsize=0.9653	 time=0.11s
# Iter:213, LossE=2.17055(0.07408)	 pmove=0.52	stepsize=0.9177	 time=0.11s
# Iter:214, LossE=2.22699(0.08180)	 pmove=0.47	stepsize=0.8724	 time=0.11s
# Iter:215, LossE=2.25604(0.07514)	 pmove=0.51	stepsize=1.0137	 time=0.11s
# Iter:216, LossE=2.23086(0.08896)	 pmove=0.51	stepsize=0.9637	 time=0.11s
# Iter:217, LossE=2.10959(0.06415)	 pmove=0.48	stepsize=0.9161	 time=0.11s
# Iter:218, LossE=2.21521(0.08415)	 pmove=0.50	stepsize=0.8709	 time=0.11s
# Iter:219, LossE=2.23367(0.08707)	 pmove=0.50	stepsize=1.0120	 time=0.10s
# Iter:220, LossE=2.24141(0.10856)	 pmove=0.50	stepsize=0.7871	 time=0.11s
# Iter:221, LossE=2.00982(0.05939)	 pmove=0.49	stepsize=0.9146	 time=0.11s
# Iter:222, LossE=2.00753(0.07378)	 pmove=0.52	stepsize=1.0627	 time=0.11s
# Iter:223, LossE=2.20327(0.06312)	 pmove=0.50	stepsize=0.8266	 time=0.11s
# Iter:224, LossE=2.26324(0.07648)	 pmove=0.52	stepsize=0.9604	 time=0.11s
# Iter:225, LossE=2.42781(0.14608)	 pmove=0.47	stepsize=0.9130	 time=0.11s
# Iter:226, LossE=2.33520(0.10060)	 pmove=0.50	stepsize=1.0609	 time=0.11s
# Iter:227, LossE=2.22793(0.11890)	 pmove=0.52	stepsize=1.0086	 time=0.11s
# Iter:228, LossE=2.18114(0.06583)	 pmove=0.53	stepsize=0.9588	 time=0.12s
# Iter:229, LossE=2.32376(0.16312)	 pmove=0.52	stepsize=0.9115	 time=0.11s
# Iter:230, LossE=2.09257(0.06624)	 pmove=0.52	stepsize=0.8665	 time=0.11s
# Iter:231, LossE=2.20353(0.07170)	 pmove=0.49	stepsize=0.8238	 time=0.12s
# Iter:232, LossE=2.22076(0.09319)	 pmove=0.53	stepsize=0.9572	 time=0.11s
# Iter:233, LossE=2.18898(0.06465)	 pmove=0.50	stepsize=0.9100	 time=0.12s
# Iter:234, LossE=2.05250(0.05427)	 pmove=0.52	stepsize=1.0573	 time=0.10s
# Iter:235, LossE=2.17077(0.07163)	 pmove=0.51	stepsize=1.0052	 time=0.12s
# Iter:236, LossE=2.35549(0.11304)	 pmove=0.53	stepsize=0.9556	 time=0.11s
# Iter:237, LossE=2.38893(0.10408)	 pmove=0.47	stepsize=0.9085	 time=0.11s
# Iter:238, LossE=2.18993(0.06785)	 pmove=0.54	stepsize=0.8636	 time=0.11s
# Iter:239, LossE=2.14789(0.07758)	 pmove=0.51	stepsize=1.0035	 time=0.11s
# Iter:240, LossE=2.19661(0.07501)	 pmove=0.53	stepsize=0.9540	 time=0.11s
# Iter:241, LossE=2.21521(0.07007)	 pmove=0.52	stepsize=0.9069	 time=0.11s
# Iter:242, LossE=2.17424(0.09085)	 pmove=0.50	stepsize=1.0538	 time=0.11s
# Iter:243, LossE=2.28698(0.07401)	 pmove=0.52	stepsize=1.0018	 time=0.11s
# Iter:244, LossE=2.17275(0.06560)	 pmove=0.50	stepsize=0.7792	 time=0.11s
# Iter:245, LossE=2.11565(0.08930)	 pmove=0.53	stepsize=0.9054	 time=0.11s
# Iter:246, LossE=2.08090(0.05471)	 pmove=0.47	stepsize=0.8607	 time=0.11s
# Iter:247, LossE=2.25494(0.10016)	 pmove=0.48	stepsize=0.8183	 time=0.11s
# Iter:248, LossE=2.07680(0.05389)	 pmove=0.51	stepsize=0.9508	 time=0.11s
# Iter:249, LossE=2.11131(0.07333)	 pmove=0.53	stepsize=0.9039	 time=0.11s
# Iter:250, LossE=2.26925(0.12856)	 pmove=0.50	stepsize=0.8593	 time=0.10s
# Iter:251, LossE=2.10420(0.06116)	 pmove=0.50	stepsize=0.8169	 time=0.11s
# Iter:252, LossE=2.06659(0.06463)	 pmove=0.50	stepsize=0.7766	 time=0.11s
# Iter:253, LossE=2.15216(0.08281)	 pmove=0.49	stepsize=0.9024	 time=0.11s
# Iter:254, LossE=2.13892(0.05993)	 pmove=0.52	stepsize=1.0485	 time=0.11s
# Iter:255, LossE=2.23244(0.06435)	 pmove=0.49	stepsize=0.8155	 time=0.11s
# Iter:256, LossE=2.15822(0.10205)	 pmove=0.47	stepsize=0.9476	 time=0.12s
# Iter:257, LossE=2.11917(0.06898)	 pmove=0.47	stepsize=0.9009	 time=0.11s
# Iter:258, LossE=2.18413(0.11822)	 pmove=0.49	stepsize=0.8564	 time=0.11s
# Iter:259, LossE=2.13056(0.06679)	 pmove=0.52	stepsize=0.9951	 time=0.11s
# Iter:260, LossE=2.12497(0.07103)	 pmove=0.52	stepsize=0.9460	 time=0.11s
# Iter:261, LossE=2.06946(0.10247)	 pmove=0.54	stepsize=0.8993	 time=0.11s
# Iter:262, LossE=2.19712(0.07381)	 pmove=0.48	stepsize=0.8550	 time=0.12s
# Iter:263, LossE=2.04558(0.05522)	 pmove=0.50	stepsize=0.8128	 time=0.11s
# Iter:264, LossE=2.13825(0.08217)	 pmove=0.50	stepsize=0.7727	 time=0.11s
# Iter:265, LossE=2.14634(0.06900)	 pmove=0.54	stepsize=0.8978	 time=0.10s
# Iter:266, LossE=2.14969(0.06379)	 pmove=0.52	stepsize=1.0432	 time=0.11s
# Iter:267, LossE=2.16847(0.11759)	 pmove=0.53	stepsize=0.9918	 time=0.11s
# Iter:268, LossE=2.04259(0.05375)	 pmove=0.48	stepsize=0.9428	 time=0.11s
# Iter:269, LossE=2.03402(0.05261)	 pmove=0.50	stepsize=0.8963	 time=0.11s
# Iter:270, LossE=2.15631(0.06185)	 pmove=0.50	stepsize=0.8521	 time=0.11s
# Iter:271, LossE=2.03965(0.04997)	 pmove=0.53	stepsize=0.9901	 time=0.11s
# Iter:272, LossE=2.11275(0.04871)	 pmove=0.52	stepsize=0.9413	 time=0.11s
# Iter:273, LossE=2.06777(0.05741)	 pmove=0.51	stepsize=1.0937	 time=0.11s
# Iter:274, LossE=2.13299(0.06069)	 pmove=0.49	stepsize=0.8507	 time=0.11s
# Iter:275, LossE=2.10158(0.06018)	 pmove=0.52	stepsize=0.9884	 time=0.11s
# Iter:276, LossE=2.11333(0.05458)	 pmove=0.50	stepsize=1.1485	 time=0.11s
# Iter:277, LossE=2.29829(0.13161)	 pmove=0.54	stepsize=1.0918	 time=0.11s
# Iter:278, LossE=2.04859(0.05039)	 pmove=0.49	stepsize=0.8493	 time=0.11s
# Iter:279, LossE=2.06497(0.05296)	 pmove=0.51	stepsize=0.9868	 time=0.12s
# Iter:280, LossE=2.06715(0.05733)	 pmove=0.49	stepsize=0.7675	 time=0.11s
# Iter:281, LossE=2.16349(0.10773)	 pmove=0.58	stepsize=0.8918	 time=0.11s
# Iter:282, LossE=2.13772(0.07309)	 pmove=0.52	stepsize=1.0362	 time=0.11s
# Iter:283, LossE=1.99806(0.04046)	 pmove=0.51	stepsize=0.9851	 time=0.11s
# Iter:284, LossE=2.03770(0.04677)	 pmove=0.53	stepsize=0.9365	 time=0.11s
# Iter:285, LossE=2.07735(0.06926)	 pmove=0.51	stepsize=1.0882	 time=0.11s
# Iter:286, LossE=2.00891(0.04468)	 pmove=0.52	stepsize=1.0345	 time=0.11s
# Iter:287, LossE=2.08988(0.05844)	 pmove=0.53	stepsize=0.9835	 time=0.12s
# Iter:288, LossE=2.12062(0.06145)	 pmove=0.48	stepsize=0.9349	 time=0.12s
# Iter:289, LossE=2.21130(0.08175)	 pmove=0.53	stepsize=0.8888	 time=0.12s
# Iter:290, LossE=2.13504(0.06574)	 pmove=0.52	stepsize=1.0328	 time=0.11s
# Iter:291, LossE=2.05384(0.05123)	 pmove=0.53	stepsize=0.9818	 time=0.11s
# Iter:292, LossE=2.03438(0.05483)	 pmove=0.54	stepsize=0.9334	 time=0.11s
# Iter:293, LossE=2.08777(0.07570)	 pmove=0.53	stepsize=0.8873	 time=0.11s
# Iter:294, LossE=2.09992(0.06903)	 pmove=0.50	stepsize=0.8436	 time=0.12s
# Iter:295, LossE=2.06573(0.04340)	 pmove=0.49	stepsize=0.8020	 time=0.12s
# Iter:296, LossE=2.14300(0.06794)	 pmove=0.48	stepsize=0.9318	 time=0.09s
# Iter:297, LossE=2.01843(0.04746)	 pmove=0.49	stepsize=0.8858	 time=0.11s
# Iter:298, LossE=1.99022(0.03787)	 pmove=0.52	stepsize=1.0293	 time=0.11s
# Iter:299, LossE=2.02444(0.04555)	 pmove=0.47	stepsize=0.9785	 time=0.11s
# Iter:300, LossE=2.26153(0.11879)	 pmove=0.49	stepsize=0.9302	 time=0.11s
# Iter:301, LossE=1.99280(0.04304)	 pmove=0.48	stepsize=0.8844	 time=0.11s
# Iter:302, LossE=2.08013(0.05763)	 pmove=0.51	stepsize=1.0276	 time=0.11s
# Iter:303, LossE=2.04307(0.04156)	 pmove=0.51	stepsize=0.9769	 time=0.11s
# Iter:304, LossE=2.11126(0.05990)	 pmove=0.51	stepsize=0.9287	 time=0.11s
# Iter:305, LossE=2.09572(0.05230)	 pmove=0.51	stepsize=1.0791	 time=0.11s
# Iter:306, LossE=2.02988(0.05678)	 pmove=0.51	stepsize=1.0258	 time=0.11s
# Iter:307, LossE=2.03189(0.03834)	 pmove=0.52	stepsize=0.9752	 time=0.11s
# Iter:308, LossE=2.02418(0.04563)	 pmove=0.55	stepsize=0.9271	 time=0.11s
# Iter:309, LossE=2.03988(0.05958)	 pmove=0.51	stepsize=1.0773	 time=0.11s
# Iter:310, LossE=1.97803(0.04149)	 pmove=0.51	stepsize=1.0241	 time=0.11s
# Iter:311, LossE=2.04352(0.04326)	 pmove=0.51	stepsize=0.9736	 time=0.10s
# Iter:312, LossE=2.11976(0.07095)	 pmove=0.50	stepsize=0.9256	 time=0.11s
# Iter:313, LossE=2.15483(0.06386)	 pmove=0.54	stepsize=0.8799	 time=0.11s
# Iter:314, LossE=1.96825(0.03977)	 pmove=0.51	stepsize=1.0224	 time=0.11s
# Iter:315, LossE=2.12518(0.07237)	 pmove=0.52	stepsize=0.9720	 time=0.12s
# Iter:316, LossE=2.40812(0.25193)	 pmove=0.54	stepsize=0.9240	 time=0.11s
# Iter:317, LossE=2.05410(0.03964)	 pmove=0.51	stepsize=1.0736	 time=0.11s
# Iter:318, LossE=2.10439(0.05951)	 pmove=0.54	stepsize=1.0207	 time=0.11s
# Iter:319, LossE=2.08991(0.05943)	 pmove=0.51	stepsize=0.9703	 time=0.11s
# Iter:320, LossE=2.04467(0.04680)	 pmove=0.49	stepsize=0.9225	 time=0.11s
# Iter:321, LossE=2.04863(0.04200)	 pmove=0.50	stepsize=0.8770	 time=0.11s
# Iter:322, LossE=1.97203(0.03765)	 pmove=0.52	stepsize=1.0190	 time=0.11s
# Iter:323, LossE=2.01811(0.03936)	 pmove=0.48	stepsize=0.9687	 time=0.11s
# Iter:324, LossE=1.99007(0.03143)	 pmove=0.53	stepsize=0.9209	 time=0.11s
# Iter:325, LossE=2.05815(0.04157)	 pmove=0.46	stepsize=0.8755	 time=0.11s
# Iter:326, LossE=2.08913(0.03653)	 pmove=0.51	stepsize=1.0173	 time=0.11s
# Iter:327, LossE=2.00484(0.03661)	 pmove=0.51	stepsize=0.9671	 time=0.10s
# Iter:328, LossE=2.05204(0.04592)	 pmove=0.53	stepsize=0.9194	 time=0.11s
# Iter:329, LossE=2.01354(0.03924)	 pmove=0.50	stepsize=0.8740	 time=0.11s
# Iter:330, LossE=1.99860(0.04451)	 pmove=0.52	stepsize=1.0155	 time=0.11s
# Iter:331, LossE=2.14793(0.09766)	 pmove=0.48	stepsize=0.7899	 time=0.11s
# Iter:332, LossE=2.07563(0.05613)	 pmove=0.49	stepsize=0.7509	 time=0.11s
# Iter:333, LossE=2.04818(0.05428)	 pmove=0.50	stepsize=1.0665	 time=0.11s
# Iter:334, LossE=2.04087(0.03996)	 pmove=0.52	stepsize=1.0138	 time=0.11s
# Iter:335, LossE=2.04365(0.04148)	 pmove=0.49	stepsize=0.7886	 time=0.12s
# Iter:336, LossE=2.09899(0.05793)	 pmove=0.48	stepsize=0.9163	 time=0.11s
# Iter:337, LossE=2.10359(0.07015)	 pmove=0.49	stepsize=0.8711	 time=0.12s
# Iter:338, LossE=2.00748(0.04382)	 pmove=0.53	stepsize=1.0121	 time=0.11s
# Iter:339, LossE=2.11935(0.07237)	 pmove=0.48	stepsize=0.9622	 time=0.11s
# Iter:340, LossE=2.07245(0.04512)	 pmove=0.52	stepsize=0.9147	 time=0.11s
# Iter:341, LossE=1.95874(0.03374)	 pmove=0.51	stepsize=1.0629	 time=0.11s
# Iter:342, LossE=2.05999(0.04111)	 pmove=0.54	stepsize=1.0104	 time=0.10s
# Iter:343, LossE=2.03517(0.04515)	 pmove=0.52	stepsize=0.9606	 time=0.12s
# Iter:344, LossE=2.07954(0.08203)	 pmove=0.48	stepsize=0.9132	 time=0.11s
# Iter:345, LossE=2.04743(0.03012)	 pmove=0.47	stepsize=0.8682	 time=0.11s
# Iter:346, LossE=2.05761(0.08316)	 pmove=0.50	stepsize=0.8253	 time=0.11s
# Iter:347, LossE=1.95893(0.02845)	 pmove=0.54	stepsize=0.9590	 time=0.12s
# Iter:348, LossE=2.01009(0.03901)	 pmove=0.56	stepsize=0.9117	 time=0.11s
# Iter:349, LossE=2.03504(0.03693)	 pmove=0.48	stepsize=0.8667	 time=0.11s
# Iter:350, LossE=2.02638(0.03903)	 pmove=0.51	stepsize=1.0071	 time=0.11s
# Iter:351, LossE=1.94701(0.03700)	 pmove=0.54	stepsize=0.9574	 time=0.12s
# Iter:352, LossE=2.00902(0.04181)	 pmove=0.53	stepsize=0.9101	 time=0.11s
# Iter:353, LossE=1.99434(0.05148)	 pmove=0.49	stepsize=0.8653	 time=0.12s
# Iter:354, LossE=1.96728(0.03425)	 pmove=0.50	stepsize=1.0054	 time=0.11s
# Iter:355, LossE=2.00708(0.04254)	 pmove=0.50	stepsize=0.7820	 time=0.12s
# Iter:356, LossE=1.98334(0.02987)	 pmove=0.50	stepsize=0.9086	 time=0.11s
# Iter:357, LossE=1.99313(0.04064)	 pmove=0.51	stepsize=1.0558	 time=0.11s
# Iter:358, LossE=2.10064(0.05593)	 pmove=0.44	stepsize=1.0037	 time=0.10s
# Iter:359, LossE=1.95534(0.03123)	 pmove=0.50	stepsize=0.9542	 time=0.12s
# Iter:360, LossE=2.02521(0.03922)	 pmove=0.53	stepsize=0.9071	 time=0.11s
# Iter:361, LossE=2.00374(0.03391)	 pmove=0.48	stepsize=0.8623	 time=0.11s
# Iter:362, LossE=1.98083(0.02967)	 pmove=0.49	stepsize=0.8198	 time=0.11s
# Iter:363, LossE=2.07645(0.03249)	 pmove=0.48	stepsize=0.9526	 time=0.11s
# Iter:364, LossE=2.08723(0.05354)	 pmove=0.51	stepsize=1.1068	 time=0.11s
# Iter:365, LossE=1.98164(0.02722)	 pmove=0.49	stepsize=0.8609	 time=0.11s
# Iter:366, LossE=2.02026(0.03685)	 pmove=0.49	stepsize=0.8184	 time=0.11s
# Iter:367, LossE=1.94501(0.02982)	 pmove=0.52	stepsize=1.1623	 time=0.12s
# Iter:368, LossE=2.00677(0.05458)	 pmove=0.51	stepsize=0.9041	 time=0.11s
# Iter:369, LossE=1.97655(0.03475)	 pmove=0.49	stepsize=0.8595	 time=0.11s
# Iter:370, LossE=2.08336(0.05583)	 pmove=0.51	stepsize=0.9986	 time=0.12s
# Iter:371, LossE=2.04457(0.05831)	 pmove=0.47	stepsize=0.9494	 time=0.11s
# Iter:372, LossE=2.11658(0.08761)	 pmove=0.48	stepsize=0.9025	 time=0.11s
# Iter:373, LossE=1.97252(0.02613)	 pmove=0.52	stepsize=1.0487	 time=0.09s
# Iter:374, LossE=2.00596(0.03564)	 pmove=0.55	stepsize=0.9970	 time=0.11s
# Iter:375, LossE=1.93867(0.03819)	 pmove=0.50	stepsize=0.9478	 time=0.12s
# Iter:376, LossE=2.04083(0.03853)	 pmove=0.47	stepsize=0.9010	 time=0.12s
# Iter:377, LossE=2.06353(0.03800)	 pmove=0.54	stepsize=1.0469	 time=0.12s
# Iter:378, LossE=2.06522(0.05642)	 pmove=0.52	stepsize=0.9953	 time=0.11s
# Iter:379, LossE=1.94614(0.02825)	 pmove=0.55	stepsize=0.9462	 time=0.12s
# Iter:380, LossE=1.99722(0.05375)	 pmove=0.48	stepsize=0.8995	 time=0.11s
# Iter:381, LossE=2.06393(0.04189)	 pmove=0.44	stepsize=1.0452	 time=0.11s
# Iter:382, LossE=1.97156(0.03351)	 pmove=0.52	stepsize=0.9936	 time=0.11s
# Iter:383, LossE=2.01971(0.03060)	 pmove=0.47	stepsize=0.9446	 time=0.12s
# Iter:384, LossE=1.97712(0.02863)	 pmove=0.49	stepsize=0.8980	 time=0.11s
# Iter:385, LossE=1.93939(0.03297)	 pmove=0.51	stepsize=1.0434	 time=0.12s
# Iter:386, LossE=2.03364(0.02653)	 pmove=0.53	stepsize=0.9919	 time=0.11s
# Iter:387, LossE=2.02580(0.04318)	 pmove=0.53	stepsize=0.9430	 time=0.11s
# Iter:388, LossE=1.95042(0.04089)	 pmove=0.51	stepsize=1.0957	 time=0.10s
# Iter:389, LossE=2.04400(0.06778)	 pmove=0.52	stepsize=1.0417	 time=0.11s
# Iter:390, LossE=2.02147(0.05143)	 pmove=0.52	stepsize=0.9903	 time=0.11s
# Iter:391, LossE=2.03714(0.04153)	 pmove=0.54	stepsize=0.9414	 time=0.11s
# Iter:392, LossE=2.12221(0.06101)	 pmove=0.46	stepsize=0.8950	 time=0.11s
# Iter:393, LossE=1.98412(0.03576)	 pmove=0.52	stepsize=0.8508	 time=0.12s
# Iter:394, LossE=1.98924(0.03474)	 pmove=0.47	stepsize=0.8089	 time=0.11s
# Iter:395, LossE=1.99377(0.05575)	 pmove=0.46	stepsize=0.9398	 time=0.12s
# Iter:396, LossE=2.01249(0.06984)	 pmove=0.47	stepsize=0.8935	 time=0.11s
# Iter:397, LossE=1.93507(0.02661)	 pmove=0.50	stepsize=1.0382	 time=0.11s
# Iter:398, LossE=2.01439(0.03117)	 pmove=0.50	stepsize=0.8075	 time=0.11s
# Iter:399, LossE=2.02000(0.04262)	 pmove=0.51	stepsize=0.9383	 time=0.12s
# Iter:400, LossE=1.98296(0.03267)	 pmove=0.56	stepsize=0.8920	 time=0.11s
# Iter:401, LossE=2.04884(0.04387)	 pmove=0.52	stepsize=1.0364	 time=0.12s
# Iter:402, LossE=1.99954(0.02870)	 pmove=0.51	stepsize=0.9853	 time=0.11s
# Iter:403, LossE=1.97089(0.04754)	 pmove=0.53	stepsize=0.9367	 time=0.12s
# Iter:404, LossE=2.05798(0.04507)	 pmove=0.50	stepsize=0.8905	 time=0.10s
# Iter:405, LossE=1.96862(0.02721)	 pmove=0.53	stepsize=0.8466	 time=0.11s
# Iter:406, LossE=2.00226(0.03193)	 pmove=0.53	stepsize=0.9836	 time=0.11s
# Iter:407, LossE=2.00459(0.02894)	 pmove=0.53	stepsize=0.9351	 time=0.11s
# Iter:408, LossE=1.91808(0.02936)	 pmove=0.49	stepsize=0.8890	 time=0.11s
# Iter:409, LossE=1.91661(0.03083)	 pmove=0.53	stepsize=1.0329	 time=0.11s
# Iter:410, LossE=2.01522(0.03097)	 pmove=0.49	stepsize=0.8034	 time=0.11s
# Iter:411, LossE=2.03143(0.03667)	 pmove=0.52	stepsize=0.9336	 time=0.11s
# Iter:412, LossE=1.98748(0.03298)	 pmove=0.48	stepsize=0.8875	 time=0.11s
# Iter:413, LossE=2.09831(0.05228)	 pmove=0.50	stepsize=0.8437	 time=0.12s
# Iter:414, LossE=1.94649(0.03015)	 pmove=0.50	stepsize=0.8021	 time=0.11s
# Iter:415, LossE=2.01935(0.03678)	 pmove=0.45	stepsize=0.9320	 time=0.11s
# Iter:416, LossE=1.99884(0.04657)	 pmove=0.51	stepsize=1.0829	 time=0.11s
# Iter:417, LossE=1.94455(0.04200)	 pmove=0.52	stepsize=1.0295	 time=0.11s
# Iter:418, LossE=2.02709(0.04090)	 pmove=0.51	stepsize=0.9787	 time=0.11s
# Iter:419, LossE=2.01749(0.04287)	 pmove=0.46	stepsize=0.9304	 time=0.10s
# Iter:420, LossE=1.95863(0.02806)	 pmove=0.48	stepsize=0.8845	 time=0.11s
# Iter:421, LossE=1.96604(0.02869)	 pmove=0.49	stepsize=0.8409	 time=0.12s
# Iter:422, LossE=1.98529(0.02677)	 pmove=0.51	stepsize=0.9771	 time=0.11s
# Iter:423, LossE=1.92115(0.02897)	 pmove=0.53	stepsize=0.9289	 time=0.11s
# Iter:424, LossE=1.97718(0.03707)	 pmove=0.49	stepsize=0.8830	 time=0.11s
# Iter:425, LossE=1.99460(0.03477)	 pmove=0.48	stepsize=0.8395	 time=0.12s
# Iter:426, LossE=2.00530(0.03028)	 pmove=0.48	stepsize=0.9754	 time=0.11s
# Iter:427, LossE=1.98825(0.03010)	 pmove=0.48	stepsize=0.9273	 time=0.12s
# Iter:428, LossE=2.01072(0.03586)	 pmove=0.48	stepsize=0.8816	 time=0.11s
# Iter:429, LossE=2.00447(0.04033)	 pmove=0.55	stepsize=1.0243	 time=0.11s
# Iter:430, LossE=2.01098(0.03022)	 pmove=0.53	stepsize=0.9738	 time=0.11s
# Iter:431, LossE=2.00996(0.02681)	 pmove=0.54	stepsize=0.9257	 time=0.11s
# Iter:432, LossE=1.97613(0.02740)	 pmove=0.48	stepsize=0.8801	 time=0.11s
# Iter:433, LossE=2.05289(0.04010)	 pmove=0.51	stepsize=1.0226	 time=0.12s
# Iter:434, LossE=2.02608(0.03075)	 pmove=0.46	stepsize=0.9721	 time=0.11s
# Iter:435, LossE=1.93866(0.03058)	 pmove=0.46	stepsize=0.9242	 time=0.11s
# Iter:436, LossE=2.00107(0.03397)	 pmove=0.49	stepsize=0.8786	 time=0.11s
# Iter:437, LossE=1.97539(0.03018)	 pmove=0.52	stepsize=1.0209	 time=0.12s
# Iter:438, LossE=2.01256(0.03683)	 pmove=0.51	stepsize=0.9705	 time=0.11s
# Iter:439, LossE=2.03098(0.03755)	 pmove=0.49	stepsize=0.9226	 time=0.11s
# Iter:440, LossE=1.97081(0.03084)	 pmove=0.55	stepsize=0.8771	 time=0.11s
# Iter:441, LossE=2.01302(0.04116)	 pmove=0.49	stepsize=0.8339	 time=0.11s
# Iter:442, LossE=1.99918(0.03885)	 pmove=0.43	stepsize=0.9689	 time=0.11s
# Iter:443, LossE=2.02164(0.03076)	 pmove=0.52	stepsize=0.9211	 time=0.11s
# Iter:444, LossE=2.06101(0.05049)	 pmove=0.50	stepsize=0.8757	 time=0.11s
# Iter:445, LossE=2.03898(0.04340)	 pmove=0.53	stepsize=1.0174	 time=0.12s
# Iter:446, LossE=2.01306(0.04142)	 pmove=0.45	stepsize=0.9673	 time=0.11s
# Iter:447, LossE=2.04240(0.04278)	 pmove=0.47	stepsize=0.9195	 time=0.11s
# Iter:448, LossE=2.01051(0.03495)	 pmove=0.48	stepsize=0.8742	 time=0.11s
# Iter:449, LossE=1.97740(0.02628)	 pmove=0.52	stepsize=1.0157	 time=0.12s
# Iter:450, LossE=1.95806(0.02867)	 pmove=0.51	stepsize=0.9656	 time=0.10s
# Iter:451, LossE=1.98443(0.03866)	 pmove=0.50	stepsize=0.9180	 time=0.11s
# Iter:452, LossE=1.94576(0.03131)	 pmove=0.50	stepsize=1.0666	 time=0.12s
# Iter:453, LossE=2.02512(0.04517)	 pmove=0.49	stepsize=0.8297	 time=0.11s
# Iter:454, LossE=1.98788(0.03237)	 pmove=0.50	stepsize=0.7887	 time=0.12s
# Iter:455, LossE=2.06970(0.04708)	 pmove=0.51	stepsize=0.9165	 time=0.12s
# Iter:456, LossE=2.02620(0.02627)	 pmove=0.50	stepsize=0.8712	 time=0.11s
# Iter:457, LossE=1.99188(0.02781)	 pmove=0.51	stepsize=1.0123	 time=0.12s
# Iter:458, LossE=2.01339(0.03760)	 pmove=0.50	stepsize=1.1763	 time=0.11s
# Iter:459, LossE=1.98245(0.02560)	 pmove=0.48	stepsize=0.9149	 time=0.11s
# Iter:460, LossE=1.95609(0.02665)	 pmove=0.54	stepsize=0.8698	 time=0.11s
# Iter:461, LossE=2.03786(0.02830)	 pmove=0.49	stepsize=0.8269	 time=0.11s
# Iter:462, LossE=1.99807(0.03309)	 pmove=0.44	stepsize=0.9608	 time=0.11s
# Iter:463, LossE=1.98094(0.02649)	 pmove=0.55	stepsize=0.9134	 time=0.12s
# Iter:464, LossE=1.95558(0.03018)	 pmove=0.50	stepsize=1.0613	 time=0.11s
# Iter:465, LossE=2.02740(0.03504)	 pmove=0.50	stepsize=0.8255	 time=0.10s
# Iter:466, LossE=2.03215(0.02920)	 pmove=0.51	stepsize=0.9592	 time=0.11s
# Iter:467, LossE=2.01205(0.03891)	 pmove=0.47	stepsize=0.9118	 time=0.11s
# Iter:468, LossE=1.95341(0.03076)	 pmove=0.50	stepsize=1.0595	 time=0.11s
# Iter:469, LossE=1.98234(0.02874)	 pmove=0.49	stepsize=0.8241	 time=0.12s
# Iter:470, LossE=1.94054(0.03101)	 pmove=0.51	stepsize=0.9576	 time=0.11s
# Iter:471, LossE=1.98070(0.02965)	 pmove=0.52	stepsize=0.9103	 time=0.12s
# Iter:472, LossE=1.98764(0.02982)	 pmove=0.49	stepsize=0.8654	 time=0.11s
# Iter:473, LossE=1.98889(0.02983)	 pmove=0.52	stepsize=1.0055	 time=0.11s
# Iter:474, LossE=1.95035(0.02685)	 pmove=0.51	stepsize=0.9559	 time=0.11s
# Iter:475, LossE=2.07150(0.08546)	 pmove=0.46	stepsize=0.9088	 time=0.12s
# Iter:476, LossE=1.98461(0.02592)	 pmove=0.50	stepsize=1.0560	 time=0.11s
# Iter:477, LossE=2.00268(0.03552)	 pmove=0.51	stepsize=1.0039	 time=0.12s
# Iter:478, LossE=1.91527(0.03079)	 pmove=0.47	stepsize=0.9543	 time=0.11s
# Iter:479, LossE=1.95616(0.02661)	 pmove=0.49	stepsize=0.9073	 time=0.11s
# Iter:480, LossE=1.97114(0.03487)	 pmove=0.52	stepsize=1.0542	 time=0.11s
# Iter:481, LossE=1.99093(0.02740)	 pmove=0.51	stepsize=1.0022	 time=0.10s
# Iter:482, LossE=1.97886(0.02868)	 pmove=0.51	stepsize=0.9527	 time=0.11s
# Iter:483, LossE=1.96718(0.02535)	 pmove=0.47	stepsize=0.9057	 time=0.12s
# Iter:484, LossE=1.99435(0.03394)	 pmove=0.52	stepsize=1.0524	 time=0.11s
# Iter:485, LossE=2.02513(0.08120)	 pmove=0.50	stepsize=0.8186	 time=0.11s
# Iter:486, LossE=1.96952(0.02690)	 pmove=0.51	stepsize=0.9511	 time=0.11s
# Iter:487, LossE=1.99482(0.03013)	 pmove=0.50	stepsize=1.1052	 time=0.12s
# Iter:488, LossE=1.96068(0.03097)	 pmove=0.51	stepsize=1.0506	 time=0.11s
# Iter:489, LossE=2.02901(0.03992)	 pmove=0.54	stepsize=0.9988	 time=0.12s
# Iter:490, LossE=1.97925(0.02930)	 pmove=0.53	stepsize=0.9495	 time=0.11s
# Iter:491, LossE=1.93642(0.02802)	 pmove=0.52	stepsize=0.9027	 time=0.11s
# Iter:492, LossE=1.98382(0.03439)	 pmove=0.53	stepsize=1.0489	 time=0.11s
# Iter:493, LossE=1.97578(0.02695)	 pmove=0.46	stepsize=0.9971	 time=0.12s
# Iter:494, LossE=1.99416(0.02738)	 pmove=0.46	stepsize=0.9479	 time=0.11s
# Iter:495, LossE=1.98205(0.02643)	 pmove=0.48	stepsize=0.9012	 time=0.12s
# Iter:496, LossE=1.94604(0.03690)	 pmove=0.49	stepsize=0.8567	 time=0.09s
# Iter:497, LossE=2.00447(0.02969)	 pmove=0.53	stepsize=0.9955	 time=0.11s
# Iter:498, LossE=1.95740(0.02651)	 pmove=0.52	stepsize=0.9464	 time=0.11s
# Iter:499, LossE=1.93271(0.02687)	 pmove=0.49	stepsize=0.8997	 time=0.11s
# Iter:500, LossE=1.92688(0.02651)	 pmove=0.50	stepsize=0.8553	 time=0.11s
# Iter:501, LossE=1.95346(0.02716)	 pmove=0.52	stepsize=0.9938	 time=0.11s
# Iter:502, LossE=1.95575(0.02835)	 pmove=0.48	stepsize=0.7730	 time=0.11s
# Iter:503, LossE=1.99650(0.02605)	 pmove=0.53	stepsize=0.8982	 time=0.12s
# Iter:504, LossE=2.00342(0.03620)	 pmove=0.49	stepsize=0.8539	 time=0.11s
# Iter:505, LossE=2.02968(0.03630)	 pmove=0.51	stepsize=0.9921	 time=0.12s
# Iter:506, LossE=1.95112(0.02587)	 pmove=0.45	stepsize=0.9432	 time=0.11s
# Iter:507, LossE=2.03279(0.05609)	 pmove=0.47	stepsize=0.8967	 time=0.11s
# Iter:508, LossE=1.97198(0.02508)	 pmove=0.49	stepsize=0.8524	 time=0.11s
# Iter:509, LossE=2.02868(0.05015)	 pmove=0.46	stepsize=0.9905	 time=0.12s
# Iter:510, LossE=1.97660(0.02656)	 pmove=0.53	stepsize=0.9416	 time=0.11s
# Iter:511, LossE=1.98701(0.02639)	 pmove=0.47	stepsize=0.8952	 time=0.10s
# Iter:512, LossE=2.00422(0.03177)	 pmove=0.49	stepsize=0.8510	 time=0.11s
# Iter:513, LossE=1.94057(0.03288)	 pmove=0.46	stepsize=0.9888	 time=0.11s
# Iter:514, LossE=2.00021(0.02591)	 pmove=0.48	stepsize=0.9400	 time=0.11s
# Iter:515, LossE=2.00241(0.02800)	 pmove=0.48	stepsize=0.8936	 time=0.12s
# Iter:516, LossE=2.00681(0.03110)	 pmove=0.52	stepsize=1.0384	 time=0.11s
# Iter:517, LossE=1.99858(0.03059)	 pmove=0.52	stepsize=0.9871	 time=0.12s
# Iter:518, LossE=2.01084(0.02669)	 pmove=0.48	stepsize=0.9384	 time=0.11s
# Iter:519, LossE=2.00801(0.02583)	 pmove=0.51	stepsize=1.0904	 time=0.11s
# Iter:520, LossE=2.02362(0.05173)	 pmove=0.50	stepsize=0.8481	 time=0.11s
# Iter:521, LossE=1.98295(0.03357)	 pmove=0.52	stepsize=0.9855	 time=0.12s
# Iter:522, LossE=1.93654(0.02838)	 pmove=0.47	stepsize=0.9369	 time=0.11s
# Iter:523, LossE=1.95851(0.02974)	 pmove=0.48	stepsize=0.8907	 time=0.11s
# Iter:524, LossE=2.00634(0.03137)	 pmove=0.48	stepsize=0.8467	 time=0.11s
# Iter:525, LossE=1.96832(0.03084)	 pmove=0.50	stepsize=0.8049	 time=0.12s
# Iter:526, LossE=2.10440(0.09711)	 pmove=0.53	stepsize=0.9353	 time=0.11s
# Iter:527, LossE=1.96648(0.02973)	 pmove=0.49	stepsize=0.8892	 time=0.10s
# Iter:528, LossE=1.97462(0.02796)	 pmove=0.51	stepsize=1.0331	 time=0.11s
# Iter:529, LossE=1.95814(0.02535)	 pmove=0.51	stepsize=0.9822	 time=0.11s
# Iter:530, LossE=2.01353(0.02694)	 pmove=0.55	stepsize=0.9337	 time=0.11s
# Iter:531, LossE=1.97013(0.02864)	 pmove=0.50	stepsize=0.8877	 time=0.11s
# Iter:532, LossE=1.94209(0.02775)	 pmove=0.51	stepsize=1.0314	 time=0.11s
# Iter:533, LossE=2.00306(0.02710)	 pmove=0.50	stepsize=0.8022	 time=0.11s
# Iter:534, LossE=1.99945(0.04236)	 pmove=0.47	stepsize=0.9322	 time=0.11s
# Iter:535, LossE=1.96752(0.02727)	 pmove=0.48	stepsize=0.8862	 time=0.12s
# Iter:536, LossE=1.98302(0.02665)	 pmove=0.49	stepsize=0.8425	 time=0.11s
# Iter:537, LossE=2.01924(0.03031)	 pmove=0.52	stepsize=0.9789	 time=0.11s
# Iter:538, LossE=1.98583(0.02493)	 pmove=0.47	stepsize=0.9306	 time=0.11s
# Iter:539, LossE=1.98100(0.02658)	 pmove=0.50	stepsize=0.8847	 time=0.12s
# Iter:540, LossE=1.98387(0.03800)	 pmove=0.49	stepsize=0.8410	 time=0.11s
# Iter:541, LossE=1.98402(0.02627)	 pmove=0.51	stepsize=0.9772	 time=0.11s
# Iter:542, LossE=1.97176(0.02723)	 pmove=0.55	stepsize=0.9290	 time=0.10s
# Iter:543, LossE=2.02114(0.02738)	 pmove=0.49	stepsize=0.8832	 time=0.11s
# Iter:544, LossE=2.03771(0.02563)	 pmove=0.50	stepsize=1.0262	 time=0.11s
# Iter:545, LossE=2.01506(0.03051)	 pmove=0.53	stepsize=0.9756	 time=0.12s
# Iter:546, LossE=1.97519(0.02866)	 pmove=0.55	stepsize=0.9275	 time=0.11s
# Iter:547, LossE=1.99136(0.02944)	 pmove=0.46	stepsize=0.8817	 time=0.12s
# Iter:548, LossE=1.97466(0.03133)	 pmove=0.55	stepsize=0.8382	 time=0.11s
# Iter:549, LossE=1.95615(0.02933)	 pmove=0.54	stepsize=0.9740	 time=0.11s
# Iter:550, LossE=1.98668(0.03262)	 pmove=0.52	stepsize=0.9259	 time=0.11s
# Iter:551, LossE=1.98804(0.02896)	 pmove=0.50	stepsize=1.0758	 time=0.12s
# Iter:552, LossE=1.98606(0.03124)	 pmove=0.48	stepsize=0.8368	 time=0.11s
# Iter:553, LossE=2.00497(0.02729)	 pmove=0.51	stepsize=0.9723	 time=0.12s
# Iter:554, LossE=1.98156(0.02508)	 pmove=0.53	stepsize=0.9244	 time=0.12s
# Iter:555, LossE=2.01917(0.03430)	 pmove=0.51	stepsize=1.0740	 time=0.11s
# Iter:556, LossE=2.00964(0.03043)	 pmove=0.50	stepsize=0.8354	 time=0.11s
# Iter:557, LossE=1.97995(0.02781)	 pmove=0.47	stepsize=0.9707	 time=0.10s
# Iter:558, LossE=1.92926(0.02520)	 pmove=0.48	stepsize=0.9228	 time=0.11s
# Iter:559, LossE=2.06554(0.03556)	 pmove=0.52	stepsize=1.0722	 time=0.12s
# Iter:560, LossE=1.96693(0.03250)	 pmove=0.51	stepsize=1.0193	 time=0.11s
# Iter:561, LossE=1.95606(0.02605)	 pmove=0.52	stepsize=0.9691	 time=0.12s
# Iter:562, LossE=2.00372(0.02791)	 pmove=0.56	stepsize=0.9213	 time=0.11s
# Iter:563, LossE=1.98964(0.02760)	 pmove=0.48	stepsize=0.8758	 time=0.11s
# Iter:564, LossE=2.01900(0.02920)	 pmove=0.49	stepsize=0.8326	 time=0.11s
# Iter:565, LossE=1.98476(0.02675)	 pmove=0.50	stepsize=0.9674	 time=0.12s
# Iter:566, LossE=1.97014(0.05314)	 pmove=0.47	stepsize=0.9197	 time=0.11s
# Iter:567, LossE=2.05018(0.02325)	 pmove=0.47	stepsize=0.8743	 time=0.12s
# Iter:568, LossE=2.00001(0.02913)	 pmove=0.50	stepsize=1.0159	 time=0.11s
# Iter:569, LossE=1.96207(0.03316)	 pmove=0.54	stepsize=0.9658	 time=0.11s
# Iter:570, LossE=2.05106(0.03944)	 pmove=0.53	stepsize=0.9182	 time=0.11s
# Iter:571, LossE=1.96736(0.02640)	 pmove=0.55	stepsize=0.8729	 time=0.11s
# Iter:572, LossE=1.97013(0.02891)	 pmove=0.53	stepsize=1.0142	 time=0.12s
# Iter:573, LossE=1.95249(0.02740)	 pmove=0.53	stepsize=0.9642	 time=0.10s
# Iter:574, LossE=1.97967(0.02915)	 pmove=0.48	stepsize=0.9166	 time=0.11s
# Iter:575, LossE=1.99842(0.02418)	 pmove=0.51	stepsize=1.0651	 time=0.12s
# Iter:576, LossE=2.03986(0.02613)	 pmove=0.51	stepsize=1.0125	 time=0.11s
# Iter:577, LossE=2.02017(0.03114)	 pmove=0.51	stepsize=0.9626	 time=0.12s
# Iter:578, LossE=2.04198(0.04822)	 pmove=0.55	stepsize=0.9151	 time=0.11s
# Iter:579, LossE=1.96485(0.02993)	 pmove=0.51	stepsize=1.0633	 time=0.11s
# Iter:580, LossE=1.95543(0.02816)	 pmove=0.49	stepsize=1.0108	 time=0.12s
# Iter:581, LossE=1.99106(0.02903)	 pmove=0.55	stepsize=0.9610	 time=0.11s
# Iter:582, LossE=1.97931(0.02635)	 pmove=0.50	stepsize=0.9136	 time=0.11s
# Iter:583, LossE=1.98911(0.03373)	 pmove=0.45	stepsize=0.8685	 time=0.11s
# Iter:584, LossE=1.96006(0.03050)	 pmove=0.46	stepsize=1.0091	 time=0.11s
# Iter:585, LossE=2.03527(0.03693)	 pmove=0.53	stepsize=0.9593	 time=0.12s
# Iter:586, LossE=1.99694(0.02981)	 pmove=0.55	stepsize=0.9120	 time=0.11s
# Iter:587, LossE=1.97205(0.03037)	 pmove=0.51	stepsize=1.0597	 time=0.11s
# Iter:588, LossE=1.96595(0.02652)	 pmove=0.51	stepsize=1.0074	 time=0.10s
# Iter:589, LossE=1.95731(0.02730)	 pmove=0.53	stepsize=0.9577	 time=0.12s
# Iter:590, LossE=1.95803(0.02713)	 pmove=0.47	stepsize=0.9105	 time=0.11s
# Iter:591, LossE=1.97075(0.02832)	 pmove=0.50	stepsize=0.8656	 time=0.11s
# Iter:592, LossE=2.02951(0.02606)	 pmove=0.53	stepsize=1.0057	 time=0.11s
# Iter:593, LossE=1.93907(0.02781)	 pmove=0.54	stepsize=0.9561	 time=0.12s
# Iter:594, LossE=1.97743(0.02679)	 pmove=0.49	stepsize=0.9090	 time=0.11s
# Iter:595, LossE=2.03975(0.06539)	 pmove=0.50	stepsize=0.8641	 time=0.11s
# Iter:596, LossE=2.03424(0.02878)	 pmove=0.51	stepsize=1.0040	 time=0.11s
# Iter:597, LossE=1.92055(0.02875)	 pmove=0.48	stepsize=0.9545	 time=0.11s
# Iter:598, LossE=2.04576(0.03006)	 pmove=0.54	stepsize=0.9074	 time=0.11s
# Iter:599, LossE=2.01242(0.03201)	 pmove=0.55	stepsize=0.8627	 time=0.11s
# Iter:600, LossE=1.99466(0.03230)	 pmove=0.52	stepsize=1.0024	 time=0.11s
# Iter:601, LossE=1.99816(0.02884)	 pmove=0.54	stepsize=0.9529	 time=0.11s
# Iter:602, LossE=1.98130(0.02592)	 pmove=0.48	stepsize=0.9059	 time=0.11s
# Iter:603, LossE=1.98624(0.02698)	 pmove=0.53	stepsize=1.0526	 time=0.11s
# Iter:604, LossE=1.98813(0.03346)	 pmove=0.50	stepsize=1.0007	 time=0.10s
# Iter:605, LossE=1.98305(0.02701)	 pmove=0.47	stepsize=0.9513	 time=0.12s
# Iter:606, LossE=2.05193(0.02806)	 pmove=0.47	stepsize=0.9044	 time=0.11s
# Iter:607, LossE=1.97902(0.02515)	 pmove=0.49	stepsize=0.8598	 time=0.12s
# Iter:608, LossE=2.07373(0.03295)	 pmove=0.54	stepsize=0.8174	 time=0.11s
# Iter:609, LossE=2.01237(0.04481)	 pmove=0.47	stepsize=0.9497	 time=0.11s
# Iter:610, LossE=1.95035(0.02691)	 pmove=0.55	stepsize=0.9029	 time=0.11s
# Iter:611, LossE=1.98717(0.02974)	 pmove=0.48	stepsize=0.8583	 time=0.11s
# Iter:612, LossE=2.04615(0.04312)	 pmove=0.50	stepsize=0.9973	 time=0.11s
# Iter:613, LossE=1.98611(0.02726)	 pmove=0.51	stepsize=0.9481	 time=0.11s
# Iter:614, LossE=1.94841(0.03095)	 pmove=0.53	stepsize=0.9014	 time=0.11s
# Iter:615, LossE=2.03149(0.04213)	 pmove=0.49	stepsize=0.8569	 time=0.11s
# Iter:616, LossE=2.02219(0.03412)	 pmove=0.51	stepsize=0.9956	 time=0.11s
# Iter:617, LossE=2.03978(0.03169)	 pmove=0.48	stepsize=0.9465	 time=0.12s
# Iter:618, LossE=1.97627(0.03262)	 pmove=0.53	stepsize=0.8998	 time=0.11s
# Iter:619, LossE=2.00878(0.02741)	 pmove=0.51	stepsize=1.0456	 time=0.10s
# Iter:620, LossE=1.95602(0.03047)	 pmove=0.44	stepsize=0.9940	 time=0.11s
# Iter:621, LossE=1.97168(0.02627)	 pmove=0.52	stepsize=0.9449	 time=0.11s
# Iter:622, LossE=1.96925(0.02771)	 pmove=0.48	stepsize=0.8983	 time=0.11s
# Iter:623, LossE=2.04359(0.02673)	 pmove=0.47	stepsize=0.8540	 time=0.12s
# Iter:624, LossE=1.95927(0.03176)	 pmove=0.47	stepsize=0.9923	 time=0.11s
# Iter:625, LossE=1.95189(0.02947)	 pmove=0.51	stepsize=0.9434	 time=0.12s
# Iter:626, LossE=1.96585(0.02546)	 pmove=0.50	stepsize=0.8968	 time=0.11s
# Iter:627, LossE=1.98877(0.02498)	 pmove=0.46	stepsize=0.8526	 time=0.11s
# Iter:628, LossE=2.01228(0.02511)	 pmove=0.50	stepsize=0.9906	 time=0.11s
# Iter:629, LossE=1.96809(0.02486)	 pmove=0.54	stepsize=0.9418	 time=0.12s
# Iter:630, LossE=2.03702(0.03480)	 pmove=0.45	stepsize=0.8953	 time=0.11s
# Iter:631, LossE=1.95259(0.02605)	 pmove=0.49	stepsize=0.8512	 time=0.11s
# Iter:632, LossE=2.04500(0.03760)	 pmove=0.53	stepsize=0.9890	 time=0.11s
# Iter:633, LossE=2.03628(0.05419)	 pmove=0.50	stepsize=0.7692	 time=0.11s
# Iter:634, LossE=2.03659(0.03016)	 pmove=0.48	stepsize=0.8938	 time=0.10s
# Iter:635, LossE=1.95831(0.02761)	 pmove=0.49	stepsize=0.8497	 time=0.12s
# Iter:636, LossE=2.03879(0.02645)	 pmove=0.50	stepsize=0.8078	 time=0.11s
# Iter:637, LossE=2.06374(0.04826)	 pmove=0.49	stepsize=0.9386	 time=0.11s
# Iter:638, LossE=2.04143(0.05217)	 pmove=0.47	stepsize=0.8923	 time=0.11s
# Iter:639, LossE=1.99420(0.03672)	 pmove=0.46	stepsize=1.0368	 time=0.12s
# Iter:640, LossE=1.98657(0.02686)	 pmove=0.53	stepsize=0.9857	 time=0.11s
# Iter:641, LossE=2.02721(0.02502)	 pmove=0.48	stepsize=0.9370	 time=0.11s
# Iter:642, LossE=1.97557(0.03806)	 pmove=0.48	stepsize=0.8908	 time=0.11s
# Iter:643, LossE=1.95358(0.03066)	 pmove=0.48	stepsize=0.8469	 time=0.11s
# Iter:644, LossE=1.98235(0.03272)	 pmove=0.54	stepsize=0.9840	 time=0.11s
# Iter:645, LossE=1.98831(0.02889)	 pmove=0.51	stepsize=0.9355	 time=0.11s
# Iter:646, LossE=1.97971(0.02952)	 pmove=0.49	stepsize=0.8893	 time=0.12s
# Iter:647, LossE=1.96056(0.03054)	 pmove=0.52	stepsize=1.0333	 time=0.12s
# Iter:648, LossE=2.06616(0.02929)	 pmove=0.48	stepsize=0.9824	 time=0.11s
# Iter:649, LossE=2.00480(0.03231)	 pmove=0.52	stepsize=0.9339	 time=0.11s
# Iter:650, LossE=1.94666(0.02742)	 pmove=0.51	stepsize=1.0851	 time=0.09s
# Iter:651, LossE=2.02937(0.02676)	 pmove=0.48	stepsize=0.8440	 time=0.11s
# Iter:652, LossE=1.94947(0.03463)	 pmove=0.49	stepsize=0.8024	 time=0.11s
# Iter:653, LossE=1.98289(0.02702)	 pmove=0.48	stepsize=0.9323	 time=0.11s
# ...
# Iter:1788, LossE=2.02039(0.02255)	 pmove=0.48	stepsize=0.9091	 time=0.11s
# Iter:1789, LossE=2.00733(0.03112)	 pmove=0.50	stepsize=1.0563	 time=0.12s
# Iter:1790, LossE=1.98280(0.02492)	 pmove=0.51	stepsize=1.0042	 time=0.10s
# Iter:1791, LossE=1.94155(0.02545)	 pmove=0.52	stepsize=0.9547	 time=0.11s
# Iter:1792, LossE=1.99606(0.02476)	 pmove=0.49	stepsize=0.9076	 time=0.11s
# Iter:1793, LossE=1.97596(0.02614)	 pmove=0.47	stepsize=0.8628	 time=0.11s
# Iter:1794, LossE=2.03297(0.02326)	 pmove=0.51	stepsize=1.0025	 time=0.11s
# Iter:1795, LossE=1.99379(0.02501)	 pmove=0.53	stepsize=0.9531	 time=0.11s
# Iter:1796, LossE=2.05384(0.02785)	 pmove=0.49	stepsize=0.9061	 time=0.11s
# Iter:1797, LossE=1.97551(0.02566)	 pmove=0.50	stepsize=1.0528	 time=0.11s
# Iter:1798, LossE=1.98778(0.02510)	 pmove=0.49	stepsize=0.8189	 time=0.11s
# Iter:1799, LossE=1.95192(0.02401)	 pmove=0.51	stepsize=0.9515	 time=0.11s
# Iter:1800, LossE=1.95573(0.03235)	 pmove=0.55	stepsize=0.9045	 time=0.11s
# Iter:1801, LossE=1.98222(0.03110)	 pmove=0.51	stepsize=1.0510	 time=0.11s
# Iter:1802, LossE=1.96540(0.02437)	 pmove=0.49	stepsize=0.8175	 time=0.11s
# Iter:1803, LossE=1.96035(0.02760)	 pmove=0.51	stepsize=0.9499	 time=0.12s
# Iter:1804, LossE=2.01047(0.02619)	 pmove=0.49	stepsize=0.9030	 time=0.11s
# Iter:1805, LossE=1.98179(0.02676)	 pmove=0.51	stepsize=1.0492	 time=0.10s
# Iter:1806, LossE=2.00616(0.02368)	 pmove=0.51	stepsize=0.9975	 time=0.11s
# Iter:1807, LossE=1.94967(0.02270)	 pmove=0.48	stepsize=0.9483	 time=0.11s
# Iter:1808, LossE=1.94260(0.02323)	 pmove=0.51	stepsize=1.1018	 time=0.11s
# Iter:1809, LossE=1.95563(0.02394)	 pmove=0.48	stepsize=0.8570	 time=0.11s
# Iter:1810, LossE=2.02142(0.02377)	 pmove=0.51	stepsize=0.9958	 time=0.11s
# Iter:1811, LossE=2.03690(0.02533)	 pmove=0.48	stepsize=0.9467	 time=0.11s
# Iter:1812, LossE=2.00827(0.02510)	 pmove=0.55	stepsize=0.9000	 time=0.11s
# Iter:1813, LossE=1.96081(0.02686)	 pmove=0.49	stepsize=0.8556	 time=0.11s
# Iter:1814, LossE=1.96495(0.02539)	 pmove=0.50	stepsize=0.9941	 time=0.11s
# Iter:1815, LossE=2.02663(0.03153)	 pmove=0.49	stepsize=0.9451	 time=0.11s
# Iter:1816, LossE=2.03758(0.02842)	 pmove=0.49	stepsize=0.8985	 time=0.11s
# Iter:1817, LossE=1.96746(0.03070)	 pmove=0.48	stepsize=0.8542	 time=0.11s
# Iter:1818, LossE=2.02079(0.02782)	 pmove=0.50	stepsize=0.9925	 time=0.11s
# Iter:1819, LossE=1.96231(0.02509)	 pmove=0.50	stepsize=1.1532	 time=0.11s
# Iter:1820, LossE=1.99378(0.02803)	 pmove=0.48	stepsize=0.8970	 time=0.11s
# Iter:1821, LossE=2.03969(0.02630)	 pmove=0.49	stepsize=0.8527	 time=0.10s
# Iter:1822, LossE=2.00674(0.02993)	 pmove=0.53	stepsize=0.9908	 time=0.11s
# Iter:1823, LossE=2.02960(0.02431)	 pmove=0.47	stepsize=0.9419	 time=0.11s
# Iter:1824, LossE=1.99298(0.03110)	 pmove=0.49	stepsize=0.8955	 time=0.11s
# Iter:1825, LossE=1.93934(0.02574)	 pmove=0.49	stepsize=0.8513	 time=0.11s
# Iter:1826, LossE=2.04548(0.02933)	 pmove=0.52	stepsize=0.9891	 time=0.11s
# Iter:1827, LossE=1.98012(0.02856)	 pmove=0.56	stepsize=0.9403	 time=0.11s
# Iter:1828, LossE=1.92184(0.02553)	 pmove=0.49	stepsize=0.8940	 time=0.11s
# Iter:1829, LossE=1.97131(0.02895)	 pmove=0.50	stepsize=0.8499	 time=0.11s
# Iter:1830, LossE=1.95005(0.02448)	 pmove=0.53	stepsize=0.9875	 time=0.11s
# Iter:1831, LossE=1.93086(0.02696)	 pmove=0.53	stepsize=0.9388	 time=0.11s
# Iter:1832, LossE=1.98547(0.02448)	 pmove=0.52	stepsize=0.8925	 time=0.11s
# Iter:1833, LossE=1.97175(0.02582)	 pmove=0.50	stepsize=0.8484	 time=0.11s
# Iter:1834, LossE=1.94933(0.02509)	 pmove=0.46	stepsize=0.9858	 time=0.11s
# Iter:1835, LossE=1.93467(0.02496)	 pmove=0.52	stepsize=0.9372	 time=0.11s
# Iter:1836, LossE=1.97723(0.02882)	 pmove=0.47	stepsize=0.8910	 time=0.10s
# Iter:1837, LossE=2.02805(0.02422)	 pmove=0.49	stepsize=0.8470	 time=0.12s
# Iter:1838, LossE=2.01842(0.02310)	 pmove=0.53	stepsize=0.9842	 time=0.11s
# Iter:1839, LossE=1.98673(0.02443)	 pmove=0.47	stepsize=0.9356	 time=0.11s
# Iter:1840, LossE=1.95188(0.02639)	 pmove=0.45	stepsize=0.8895	 time=0.11s
# Iter:1841, LossE=2.02727(0.02351)	 pmove=0.50	stepsize=1.0335	 time=0.11s
# Iter:1842, LossE=1.98309(0.02328)	 pmove=0.49	stepsize=0.8039	 time=0.11s
# Iter:1843, LossE=1.94255(0.02879)	 pmove=0.54	stepsize=0.9340	 time=0.11s
# Iter:1844, LossE=1.97805(0.02689)	 pmove=0.48	stepsize=0.8880	 time=0.11s
# Iter:1845, LossE=1.99807(0.02431)	 pmove=0.46	stepsize=1.0318	 time=0.11s
# Iter:1846, LossE=2.02337(0.02387)	 pmove=0.53	stepsize=0.9809	 time=0.11s
# Iter:1847, LossE=1.96197(0.02688)	 pmove=0.50	stepsize=0.7629	 time=0.11s
# Iter:1848, LossE=1.99864(0.03380)	 pmove=0.51	stepsize=1.0835	 time=0.11s
# Iter:1849, LossE=1.99642(0.02647)	 pmove=0.51	stepsize=1.0300	 time=0.11s
# Iter:1850, LossE=1.98312(0.02622)	 pmove=0.51	stepsize=0.9792	 time=0.11s
# Iter:1851, LossE=1.96979(0.02406)	 pmove=0.49	stepsize=0.9309	 time=0.11s
# Iter:1852, LossE=2.13380(0.08843)	 pmove=0.51	stepsize=1.0817	 time=0.10s
# Iter:1853, LossE=2.01023(0.02275)	 pmove=0.52	stepsize=1.0283	 time=0.11s
# Iter:1854, LossE=1.97981(0.02579)	 pmove=0.53	stepsize=0.9776	 time=0.11s
# Iter:1855, LossE=1.96021(0.02476)	 pmove=0.47	stepsize=0.9294	 time=0.11s
# Iter:1856, LossE=1.96714(0.02840)	 pmove=0.47	stepsize=0.8835	 time=0.11s
# Iter:1857, LossE=1.98812(0.02252)	 pmove=0.51	stepsize=1.0266	 time=0.11s
# Iter:1858, LossE=2.02141(0.02484)	 pmove=0.51	stepsize=0.9759	 time=0.11s
# Iter:1859, LossE=1.97331(0.02699)	 pmove=0.52	stepsize=0.9278	 time=0.11s
# Iter:1860, LossE=1.95941(0.02683)	 pmove=0.50	stepsize=0.8820	 time=0.11s
# Iter:1861, LossE=2.01770(0.03686)	 pmove=0.51	stepsize=1.0249	 time=0.11s
# Iter:1862, LossE=1.97760(0.02504)	 pmove=0.49	stepsize=0.7972	 time=0.11s
# Iter:1863, LossE=1.95544(0.02673)	 pmove=0.47	stepsize=0.9262	 time=0.11s
# Iter:1864, LossE=2.03270(0.02439)	 pmove=0.46	stepsize=0.8805	 time=0.11s
# Iter:1865, LossE=1.97903(0.02867)	 pmove=0.51	stepsize=1.0231	 time=0.11s
# Iter:1866, LossE=1.90829(0.02498)	 pmove=0.51	stepsize=0.9727	 time=0.11s
# Iter:1867, LossE=1.97201(0.02308)	 pmove=0.50	stepsize=0.9247	 time=0.10s
# Iter:1868, LossE=2.00452(0.02517)	 pmove=0.50	stepsize=1.0744	 time=0.11s
# Iter:1869, LossE=2.03187(0.03612)	 pmove=0.53	stepsize=1.0214	 time=0.12s
# Iter:1870, LossE=1.93842(0.02530)	 pmove=0.50	stepsize=0.7945	 time=0.11s
# Iter:1871, LossE=1.99367(0.02703)	 pmove=0.53	stepsize=0.9231	 time=0.11s
# Iter:1872, LossE=1.96517(0.02513)	 pmove=0.48	stepsize=0.8776	 time=0.11s
# Iter:1873, LossE=1.98421(0.02626)	 pmove=0.51	stepsize=1.0197	 time=0.11s
# Iter:1874, LossE=1.96560(0.02421)	 pmove=0.51	stepsize=0.9694	 time=0.11s
# Iter:1875, LossE=2.00937(0.02451)	 pmove=0.46	stepsize=0.9216	 time=0.11s
# Iter:1876, LossE=1.97818(0.02512)	 pmove=0.50	stepsize=1.0708	 time=0.11s
# Iter:1877, LossE=2.01113(0.02869)	 pmove=0.47	stepsize=0.8329	 time=0.12s
# Iter:1878, LossE=2.01005(0.02424)	 pmove=0.51	stepsize=0.9678	 time=0.11s
# Iter:1879, LossE=1.97374(0.03186)	 pmove=0.46	stepsize=0.9200	 time=0.11s
# Iter:1880, LossE=1.94703(0.02537)	 pmove=0.50	stepsize=0.8746	 time=0.11s
# Iter:1881, LossE=2.01553(0.02381)	 pmove=0.49	stepsize=0.8315	 time=0.11s
# Iter:1882, LossE=1.94712(0.02655)	 pmove=0.52	stepsize=0.9661	 time=0.11s
# Iter:1883, LossE=1.97349(0.02493)	 pmove=0.49	stepsize=0.9185	 time=0.10s
# Iter:1884, LossE=2.01100(0.02420)	 pmove=0.48	stepsize=0.8732	 time=0.11s
# Iter:1885, LossE=2.03887(0.02547)	 pmove=0.48	stepsize=0.8301	 time=0.11s
# Iter:1886, LossE=1.99149(0.02844)	 pmove=0.54	stepsize=0.9645	 time=0.11s
# Iter:1887, LossE=1.99687(0.02397)	 pmove=0.51	stepsize=1.1207	 time=0.11s
# Iter:1888, LossE=1.97416(0.02905)	 pmove=0.48	stepsize=0.8717	 time=0.11s
# Iter:1889, LossE=1.99986(0.02615)	 pmove=0.52	stepsize=1.0129	 time=0.11s
# Iter:1890, LossE=1.92307(0.02733)	 pmove=0.54	stepsize=0.9629	 time=0.11s
# Iter:1891, LossE=1.99244(0.02386)	 pmove=0.48	stepsize=0.9154	 time=0.11s
# Iter:1892, LossE=2.01302(0.02786)	 pmove=0.52	stepsize=0.8702	 time=0.11s
# Iter:1893, LossE=1.94959(0.02276)	 pmove=0.51	stepsize=1.0112	 time=0.11s
# Iter:1894, LossE=1.99167(0.02502)	 pmove=0.54	stepsize=0.9613	 time=0.11s
# Iter:1895, LossE=1.96909(0.02746)	 pmove=0.51	stepsize=0.9139	 time=0.11s
# Iter:1896, LossE=1.99630(0.02676)	 pmove=0.48	stepsize=0.8688	 time=0.11s
# Iter:1897, LossE=1.98550(0.02486)	 pmove=0.44	stepsize=1.0095	 time=0.11s
# Iter:1898, LossE=1.99571(0.02417)	 pmove=0.45	stepsize=0.9597	 time=0.10s
# Iter:1899, LossE=1.99840(0.02429)	 pmove=0.52	stepsize=0.9123	 time=0.11s
# Iter:1900, LossE=1.98986(0.02455)	 pmove=0.58	stepsize=0.8673	 time=0.11s
# Iter:1901, LossE=2.01041(0.02853)	 pmove=0.48	stepsize=0.8245	 time=0.11s
# Iter:1902, LossE=1.92286(0.02738)	 pmove=0.52	stepsize=0.9581	 time=0.11s
# Iter:1903, LossE=1.99951(0.02400)	 pmove=0.50	stepsize=0.9108	 time=0.11s
# Iter:1904, LossE=2.00619(0.02417)	 pmove=0.49	stepsize=0.8659	 time=0.11s
# Iter:1905, LossE=1.96009(0.02294)	 pmove=0.55	stepsize=0.8232	 time=0.12s
# Iter:1906, LossE=1.99153(0.02336)	 pmove=0.55	stepsize=0.9565	 time=0.11s
# Iter:1907, LossE=1.96795(0.02591)	 pmove=0.51	stepsize=1.1113	 time=0.11s
# Iter:1908, LossE=1.97843(0.02300)	 pmove=0.47	stepsize=0.8644	 time=0.11s
# Iter:1909, LossE=1.96852(0.02472)	 pmove=0.51	stepsize=1.0044	 time=0.12s
# Iter:1910, LossE=1.95503(0.02482)	 pmove=0.52	stepsize=0.9549	 time=0.11s
# Iter:1911, LossE=2.04105(0.02332)	 pmove=0.52	stepsize=0.9077	 time=0.11s
# Iter:1912, LossE=2.00070(0.02253)	 pmove=0.51	stepsize=1.0547	 time=0.11s
# Iter:1913, LossE=1.99468(0.02391)	 pmove=0.51	stepsize=1.0027	 time=0.11s
# Iter:1914, LossE=1.93267(0.02615)	 pmove=0.48	stepsize=0.9532	 time=0.10s
# Iter:1915, LossE=1.95959(0.02454)	 pmove=0.55	stepsize=0.9062	 time=0.11s
# Iter:1916, LossE=2.00546(0.02301)	 pmove=0.49	stepsize=0.8615	 time=0.11s
# Iter:1917, LossE=1.95891(0.02415)	 pmove=0.48	stepsize=0.8190	 time=0.12s
# Iter:1918, LossE=2.00442(0.02339)	 pmove=0.50	stepsize=0.9516	 time=0.11s
# Iter:1919, LossE=1.96591(0.02498)	 pmove=0.50	stepsize=1.1057	 time=0.11s
# Iter:1920, LossE=1.97933(0.02396)	 pmove=0.50	stepsize=0.8601	 time=0.12s
# Iter:1921, LossE=1.98239(0.02630)	 pmove=0.48	stepsize=0.8176	 time=0.11s
# Iter:1922, LossE=2.00005(0.02391)	 pmove=0.53	stepsize=0.9500	 time=0.11s
# Iter:1923, LossE=1.97872(0.02314)	 pmove=0.49	stepsize=0.9032	 time=0.12s
# Iter:1924, LossE=1.98277(0.02402)	 pmove=0.49	stepsize=0.8586	 time=0.11s
# Iter:1925, LossE=2.01802(0.03514)	 pmove=0.51	stepsize=0.9977	 time=0.11s
# Iter:1926, LossE=1.99643(0.02462)	 pmove=0.48	stepsize=0.9485	 time=0.11s
# Iter:1927, LossE=1.97017(0.02395)	 pmove=0.51	stepsize=1.1020	 time=0.12s
# Iter:1928, LossE=1.96874(0.02577)	 pmove=0.50	stepsize=0.8572	 time=0.12s
# Iter:1929, LossE=1.99878(0.02421)	 pmove=0.47	stepsize=0.8149	 time=0.10s
# Iter:1930, LossE=1.97009(0.02522)	 pmove=0.54	stepsize=0.9469	 time=0.12s
# Iter:1931, LossE=1.97047(0.02413)	 pmove=0.55	stepsize=0.9002	 time=0.11s
# Iter:1932, LossE=1.97546(0.02453)	 pmove=0.49	stepsize=0.8558	 time=0.12s
# Iter:1933, LossE=1.97333(0.02355)	 pmove=0.48	stepsize=0.8135	 time=0.11s
# Iter:1934, LossE=2.00993(0.02462)	 pmove=0.52	stepsize=0.9453	 time=0.11s
# Iter:1935, LossE=1.97159(0.02589)	 pmove=0.54	stepsize=0.8986	 time=0.11s
# Iter:1936, LossE=2.00673(0.02643)	 pmove=0.48	stepsize=0.8543	 time=0.11s
# Iter:1937, LossE=1.97052(0.03765)	 pmove=0.54	stepsize=0.9927	 time=0.11s
# Iter:1938, LossE=1.98747(0.02683)	 pmove=0.54	stepsize=0.9437	 time=0.11s
# Iter:1939, LossE=1.99982(0.02504)	 pmove=0.51	stepsize=1.0965	 time=0.11s
# Iter:1940, LossE=1.97146(0.02632)	 pmove=0.50	stepsize=1.0424	 time=0.11s
# Iter:1941, LossE=1.99152(0.02593)	 pmove=0.50	stepsize=0.8108	 time=0.11s
# Iter:1942, LossE=1.99417(0.02581)	 pmove=0.50	stepsize=0.9421	 time=0.11s
# Iter:1943, LossE=1.98437(0.02514)	 pmove=0.51	stepsize=1.0947	 time=0.11s
# Iter:1944, LossE=1.99200(0.02365)	 pmove=0.50	stepsize=0.8514	 time=0.09s
# Iter:1945, LossE=1.99167(0.02434)	 pmove=0.51	stepsize=0.9893	 time=0.11s
# Iter:1946, LossE=1.98739(0.02596)	 pmove=0.52	stepsize=0.9405	 time=0.11s
# Iter:1947, LossE=1.97016(0.02494)	 pmove=0.51	stepsize=1.0928	 time=0.12s
# Iter:1948, LossE=1.99232(0.02195)	 pmove=0.52	stepsize=1.0389	 time=0.11s
# Iter:1949, LossE=1.98784(0.02244)	 pmove=0.52	stepsize=0.9877	 time=0.11s
# Iter:1950, LossE=1.99950(0.02236)	 pmove=0.51	stepsize=0.9389	 time=0.11s
# Iter:1951, LossE=1.93662(0.02365)	 pmove=0.57	stepsize=0.8926	 time=0.11s
# Iter:1952, LossE=2.02203(0.02495)	 pmove=0.50	stepsize=1.0372	 time=0.11s
# Iter:1953, LossE=1.98296(0.03033)	 pmove=0.52	stepsize=0.9860	 time=0.11s
# Iter:1954, LossE=1.98725(0.02423)	 pmove=0.55	stepsize=0.9374	 time=0.11s
# Iter:1955, LossE=1.95744(0.02483)	 pmove=0.56	stepsize=0.8911	 time=0.11s
# Iter:1956, LossE=1.98857(0.02986)	 pmove=0.50	stepsize=1.0354	 time=0.11s
# Iter:1957, LossE=1.97737(0.02733)	 pmove=0.54	stepsize=0.9843	 time=0.11s
# Iter:1958, LossE=1.97766(0.02698)	 pmove=0.49	stepsize=0.9358	 time=0.11s
# Iter:1959, LossE=1.98642(0.02480)	 pmove=0.46	stepsize=0.8896	 time=0.11s
# Iter:1960, LossE=1.99588(0.02561)	 pmove=0.51	stepsize=1.0337	 time=0.10s
# Iter:1961, LossE=2.02372(0.04155)	 pmove=0.50	stepsize=0.9827	 time=0.11s
# Iter:1962, LossE=2.00023(0.02387)	 pmove=0.52	stepsize=0.9342	 time=0.11s
# Iter:1963, LossE=1.99042(0.02448)	 pmove=0.44	stepsize=0.8881	 time=0.11s
# Iter:1964, LossE=2.00167(0.02255)	 pmove=0.51	stepsize=1.0320	 time=0.11s
# Iter:1965, LossE=1.97072(0.02696)	 pmove=0.56	stepsize=0.9810	 time=0.11s
# Iter:1966, LossE=2.03748(0.02277)	 pmove=0.54	stepsize=0.9327	 time=0.11s
# Iter:1967, LossE=2.00254(0.02432)	 pmove=0.49	stepsize=0.8866	 time=0.12s
# Iter:1968, LossE=1.97172(0.02604)	 pmove=0.51	stepsize=1.0302	 time=0.11s
# Iter:1969, LossE=2.00482(0.02480)	 pmove=0.53	stepsize=0.9794	 time=0.11s
# Iter:1970, LossE=1.98490(0.02432)	 pmove=0.47	stepsize=0.9311	 time=0.11s
# Iter:1971, LossE=1.98697(0.02518)	 pmove=0.49	stepsize=0.8852	 time=0.11s
# Iter:1972, LossE=1.97579(0.02557)	 pmove=0.49	stepsize=0.8415	 time=0.11s
# Iter:1973, LossE=2.00863(0.04721)	 pmove=0.53	stepsize=0.9778	 time=0.11s
# Iter:1974, LossE=1.98969(0.02329)	 pmove=0.51	stepsize=0.9295	 time=0.11s
# Iter:1975, LossE=1.93568(0.02519)	 pmove=0.51	stepsize=1.0800	 time=0.10s
# Iter:1976, LossE=1.96284(0.03302)	 pmove=0.49	stepsize=0.8401	 time=0.11s
# Iter:1977, LossE=1.96538(0.02622)	 pmove=0.49	stepsize=0.9761	 time=0.11s
# Iter:1978, LossE=1.95903(0.02480)	 pmove=0.53	stepsize=0.9280	 time=0.11s
# Iter:1979, LossE=1.95348(0.02422)	 pmove=0.51	stepsize=1.0782	 time=0.11s
# Iter:1980, LossE=1.91313(0.02674)	 pmove=0.51	stepsize=1.0250	 time=0.11s
# Iter:1981, LossE=1.97769(0.02399)	 pmove=0.51	stepsize=0.9745	 time=0.12s
# Iter:1982, LossE=1.99162(0.02350)	 pmove=0.49	stepsize=0.9264	 time=0.11s
# Iter:1983, LossE=1.97781(0.02526)	 pmove=0.50	stepsize=0.8807	 time=0.11s
# Iter:1984, LossE=1.99100(0.02443)	 pmove=0.47	stepsize=1.0233	 time=0.11s
# Iter:1985, LossE=2.00622(0.03366)	 pmove=0.52	stepsize=0.9728	 time=0.12s
# Iter:1986, LossE=1.98411(0.02508)	 pmove=0.56	stepsize=0.9249	 time=0.11s
# Iter:1987, LossE=1.97818(0.02236)	 pmove=0.47	stepsize=0.8792	 time=0.11s
# Iter:1988, LossE=1.95842(0.02598)	 pmove=0.51	stepsize=1.0216	 time=0.11s
# Iter:1989, LossE=1.98979(0.02466)	 pmove=0.49	stepsize=0.9712	 time=0.11s
# Iter:1990, LossE=1.95004(0.02640)	 pmove=0.46	stepsize=0.9233	 time=0.10s
# Iter:1991, LossE=1.96442(0.02493)	 pmove=0.53	stepsize=0.8778	 time=0.11s
# Iter:1992, LossE=2.01968(0.02157)	 pmove=0.51	stepsize=1.0199	 time=0.11s
# Iter:1993, LossE=2.00343(0.02101)	 pmove=0.52	stepsize=0.9696	 time=0.11s
# Iter:1994, LossE=1.99056(0.02444)	 pmove=0.48	stepsize=0.9217	 time=0.11s
# Iter:1995, LossE=1.90659(0.02966)	 pmove=0.53	stepsize=1.0710	 time=0.11s
# Iter:1996, LossE=1.98385(0.02272)	 pmove=0.50	stepsize=0.8331	 time=0.11s
# Iter:1997, LossE=1.97903(0.02396)	 pmove=0.50	stepsize=0.9679	 time=0.11s
# Iter:1998, LossE=1.97692(0.02493)	 pmove=0.48	stepsize=0.9202	 time=0.11s
# Iter:1999, LossE=1.96755(0.02286)	 pmove=0.49	stepsize=0.8748	 time=0.11s
# ...Inferencing...
# Thermalization...
# After Thermalization:	pmove 0.50	step_size=0.8317	time=5.11s
# Mesuring Energy...
# n=0	energy=0.24770(0.01792)
# n=1	energy=1.74679(0.01869)
# ======================================
# Excitation States
# ======================================
